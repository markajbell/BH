# %% [markdown]
# <a href="https://colab.research.google.com/github/markajbell/BH/blob/main/Stats_vul_5k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !pip install pyvis

import pandas as pd
import numpy as np
import json
import os
import glob
import re
# Out:
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9.6->pyvis) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 13.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.0 MB/s eta 0:00:00
# Installing collected packages: jedi, pyvis
# Successfully installed jedi-0.19.2 pyvis-0.3.2

# %%
pd.set_option('display.max_rows', None)
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
# !wget https://raw.githubusercontent.com/markajbell/BH/refs/heads/main/adsync/vul5k.json

if not os.path.exists('/content/adsync'):
    os.makedirs('/content/adsync')
    print("/content/adsync directory created.")
else:
    print("/content/adsync directory already exists.")

path = "/content/adsync"

# !mv vul5k.json /content/adsync



data = {}
json_files = glob.glob(os.path.join(path, "*.json"))
for file in json_files:
    filename = os.path.basename(file).replace(".json", "")
    suf = filename.split("_")[-1]

    with open(file, 'r', encoding='utf-8') as f:
        content = json.load(f)

    if "data" in content:
        if suf in data:
            data[f"{suf}"].extend(content["data"])
            #print(f" The key 'data' was found in {f}.")
        else:
            data[f"{suf}"] = content["data"]
            #print(f" The key 'data' was found in {f}.")
    else:
        print(f"Warning: The key 'data' was not found in {f}.")

# %%
# prompt: if the type column = "node" save that record into a pandas dataframe called nodes, if the type = "relationship' then save to a pandas dataframe called edges


df = pd.DataFrame(data[suf])
nodes = df[df['type'] == 'node'].copy()
edges = df[df['type'] == 'relationship'].copy()
nodes['id'] = nodes['id'].astype(int)

# %%
# prompt: for every record in "nodes" create a l1, l2 and l3 column for the values in "nodes.labels" eg. for record 1 l1=Base, l2=OU and l3 would be null

import pandas as pd
def extract_labels(labels):
    # Ensure labels is a list
    if not isinstance(labels, list):
        return [None, None, None]

    l1 = labels[0] if len(labels) > 0 else None
    l2 = labels[1] if len(labels) > 1 else None
    l3 = labels[2] if len(labels) > 2 else None
    return [l1, l2, l3]

# Apply the function to create the new columns
nodes[['l1', 'l2', 'l3']] = nodes['labels'].apply(lambda x: pd.Series(extract_labels(x)))

# %%
nodes = nodes.drop(columns=['start', 'end', 'label', 'labels'])
# edges = edges.drop(columns=['labels'])

# %%
edges.head()
# Out:
#        id labels properties          type  \
# 5274  r_0    NaN         {}  relationship
# 5275  r_1    NaN         {}  relationship
# 5276  r_2    NaN         {}  relationship
# 5277  r_3    NaN         {}  relationship
# 5278  r_4    NaN         {}  relationship
#
#                                              start  \
# 5274  {'id': '4248', 'labels': ['Base', 'Domain']}
# 5275  {'id': '4248', 'labels': ['Base', 'Domain']}
# 5276  {'id': '4248', 'labels': ['Base', 'Domain']}
# 5277      {'id': '4249', 'labels': ['Base', 'OU']}
# 5278      {'id': '4249', 'labels': ['Base', 'OU']}
#
#                                            end     label
# 5274  {'id': '4249', 'labels': ['Base', 'OU']}  Contains
# 5275  {'id': '4250', 'labels': ['Base', 'OU']}  Contains
# 5276  {'id': '4251', 'labels': ['Base', 'OU']}  Contains
# 5277  {'id': '4252', 'labels': ['Base', 'OU']}  Contains
# 5278  {'id': '4253', 'labels': ['Base', 'OU']}  Contains

# %%
edges['source'] = edges['start'].apply(lambda x: x.get('id'))
edges['source_node'] = edges['start'].apply(lambda x: x.get('labels')[1] if isinstance(x.get('labels'), list) and len(x.get('labels')) > 1 else None)

edges['target'] = edges['end'].apply(lambda x: x.get('id'))
edges['target_node'] = edges['end'].apply(lambda x: x.get('labels')[1] if isinstance(x.get('labels'), list) and len(x.get('labels')) > 1 else None)

edges = edges.drop(columns=['properties', 'start', 'end', 'id', 'labels'])
edges['id'] = np.arange(len(edges)).astype('int64')
edges = edges.reset_index(drop=True)
nodes['weight'] = 1
edges = edges[['id', 'source', 'source_node', 'target', 'target_node', 'type','label']]
display(edges.head())
edges.info()
# Out:
#    id source source_node target target_node          type     label
# 0   0   4248      Domain   4249          OU  relationship  Contains
# 1   1   4248      Domain   4250          OU  relationship  Contains
# 2   2   4248      Domain   4251          OU  relationship  Contains
# 3   3   4249          OU   4252          OU  relationship  Contains
# 4   4   4249          OU   4253          OU  relationship  Contains

# %%
#edges = edges.drop(columns=['id'])
nodes.info()
nodes.head()
# Out:
#      id          labels                                         properties  \
# 0  4248  [Base, Domain]  {'domain': 'TESTLAB.LOCALE', 'name': 'TESTLAB....
# 1  4249      [Base, OU]  {'domain': 'TESTLAB.LOCALE', 'name': 'Admin@TE...
# 2  4250      [Base, OU]  {'domain': 'TESTLAB.LOCALE', 'name': 'Tier 1 S...
# 3  4251      [Base, OU]  {'domain': 'TESTLAB.LOCALE', 'name': 'Tier 2@T...
# 4  4252      [Base, OU]  {'domain': 'TESTLAB.LOCALE', 'name': 'T0 Admin...
#
#    type start  end label    l1      l2    l3  weight
# 0  node   NaN  NaN   NaN  Base  Domain  None       1
# 1  node   NaN  NaN   NaN  Base      OU  None       1
# 2  node   NaN  NaN   NaN  Base      OU  None       1
# 3  node   NaN  NaN   NaN  Base      OU  None       1
# 4  node   NaN  NaN   NaN  Base      OU  None       1

# %%
lastnode=(len(str(nodes['id'].iloc[-1])))

new_node_id = int('9' * lastnode)

print(f"The new node ID is: {new_node_id}")
# Out:
# The new node ID is: 9999

# %%
#prompt: create a new record in nodes where id=new_node_id, properties = {'domain': 'TESTLAB.LOCALE', 'name': 'ALL_T0@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-99999', 'distinguishedname': 'CN=ALL_T0,OU=ALL_T0,OU=ALL_T0,DC=TESTLAB,DC=LOCALE', 'description': 'All Tier 0 nodes', 'highvalue': True, 'admincount': True, 'owned': False}, type=node, l1=ALL_T0, l2=ALL_T0, l3=ALL_T0

# Create a dictionary with the new record's data
new_node_data = {
    'id': new_node_id,
    'properties': {'domain': 'TESTLAB.LOCALE', 'name': 'ALL_T0@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-' + str(new_node_id), 'distinguishedname': 'CN=ALL_T0,OU=ALL_T0,OU=ALL_T0,DC=TESTLAB,DC=LOCALE', 'description': 'All Tier 0 nodes', 'highvalue': True, 'admincount': True, 'owned': False},
    'type': 'node',
    'l1': 'ALL_T0',
    'l2': 'ALL_T0',
    'l3': 'ALL_T0',
    'weight': int(100) # Assuming a default weight, you can adjust if needed
}
#new_node_data

# Convert the dictionary to a DataFrame
new_node_df = pd.DataFrame([new_node_data])

# Concatenate the new DataFrame with the existing nodes DataFrame
nodes = pd.concat([nodes, new_node_df], ignore_index=True)

# Display the last few rows to confirm the addition
print("Nodes DataFrame after adding the new record:")
#display(nodes.tail())
# Out:
# Nodes DataFrame after adding the new record:

# %%
print(nodes[nodes['id'] == 26])
# print(nodes[nodes['id'] == 15])
# print(nodes[nodes['id'] == 26])
# print(nodes[nodes['id'] == 27])
# print(nodes[nodes['id'] == 637])
# print(nodes[nodes['id'] == 581])
# print(nodes[nodes['id'] == 633])
# print(nodes[nodes['id'] == 869])
# Out:
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight]
# Index: []

# %%
#1/0
# tier0_node_ids = nodes[nodes['properties'].apply(lambda x: 'Tier 0' in x.get('distinguishedname', ''))]['id'].tolist()
# tier0_node_ids
tier0_node_ids = []
tier0_node_ids = nodes[
    nodes['properties'].apply(
        lambda x: any(
            term in x.get('distinguishedname', '')
            for term in ['TIER 0', 'Tier 0', 'T0', 'TIER0']
        )
    )
]['id'].tolist()

filtered_nodes = nodes[
    nodes['properties'].apply(
        lambda x: re.search(r'.*-5[0-9]{2}$', x.get('objectid', '')) is not None and
                  x.get('highvalue', False) == True and
                  x.get('admincount', False) == True
    )
]

len(filtered_nodes)
# Iterate through the 'id' column of the filtered_nodes DataFrame
for node_id in filtered_nodes['id']:
    # Check if the node_id is not already in tier0_node_ids
    if node_id not in tier0_node_ids:
        # Append the node_id to the tier0_node_ids list
        tier0_node_ids.append(node_id)

# Print the updated length and contents of tier0_node_ids
print(f"tier 0 (after checking filtered_nodes): {len(tier0_node_ids)}")

print("Updated Tier 0 Node IDs:", tier0_node_ids)

for index, row in nodes.iterrows():
    properties = row['properties']
    node_id = row['id']

    # Check if 'properties' is a dictionary and contains 'distinguishedname'
    if isinstance(properties, dict) and 'distinguishedname' in properties:
        distinguishedname = properties['distinguishedname']

        # Check if "CN=Enterprise Admins," or "CN=Domain Admins," is in the distinguishedname
        if "CN=Enterprise Admins," in distinguishedname or "CN=Domain Admins," in distinguishedname or "CN=Administrator," in distinguishedname:
            # Append the id if it's not already in the list
            if node_id not in tier0_node_ids:
                tier0_node_ids.append(node_id)
# Out:
# tier 0 (after checking filtered_nodes): 264
# Updated Tier 0 Node IDs: [4252, 4255, 4256, 4257, 4258, 4335, 4405, 4406, 4408, 4411, 4414, 4415, 4420, 4434, 4435, 4437, 4440, 4442, 4446, 4448, 4449, 4451, 4452, 4454, 4456, 4460, 4464, 4465, 4467, 4473, 4474, 4476, 4479, 4481, 4484, 4485, 4487, 4489, 4494, 4496, 4504, 4510, 4511, 4512, 4514, 4516, 4517, 4534, 4535, 4536, 4540, 4541, 4552, 4553, 4556, 4557, 4558, 4559, 4561, 4562, 4566, 4568, 4570, 4572, 4631, 4649, 4679, 4711, 4713, 4731, 4765, 4808, 4827, 4828, 4851, 4853, 4857, 4865, 4885, 4889, 4929, 4983, 5005, 5009, 5030, 5036, 5039, 5103, 5121, 5131, 5171, 5184, 5194, 5215, 5237, 5260, 5264, 5282, 5305, 5309, 5322, 5328, 5356, 5358, 5362, 5368, 5372, 5373, 5400, 5408, 5442, 5460, 5478, 5481, 5527, 5555, 5574, 5596, 5610, 5623, 5649, 5658, 5694, 5697, 5713, 5714, 5727, 5731, 5732, 5802, 5828, 5836, 5840, 5856, 5881, 5909, 5914, 5915, 5945, 5967, 6009, 6020, 6063, 6118, 6120, 6124, 6140, 6181, 6205, 6218, 6219, 6258, 6270, 6289, 6301, 6316, 6322, 6372, 6385, 6406, 6417, 6428, 6433, 6456, 6472, 6487, 6547, 6548, 6586, 6589, 6617, 6636, 6687, 6712, 6728, 6763, 6773, 6777, 6787, 6789, 6798, 6799, 6810, 6836, 6858, 6884, 6893, 6898, 6906, 6924, 6932, 6935, 6938, 6955, 6957, 6990, 6992, 6996, 7002, 7003, 7005, 7006, 7011, 7014, 7015, 7027, 7035, 7036, 7050, 7053, 7066, 7077, 7082, 7093, 7111, 7117, 7136, 7153, 7215, 7222, 7274, 7278, 7296, 7304, 7325, 7343, 7347, 7379, 7381, 7393, 7400, 7411, 7418, 7419, 7420, 7429, 7445, 7446, 7455, 7470, 7482, 7543, 7555, 7564, 7647, 7675, 7678, 7724, 7727, 7736, 7744, 7751, 7776, 7798, 7804, 9999, 4288, 4290, 4292, 4311, 4312, 4317, 4318, 4324]

# %%
tier1_node_ids = nodes[
    nodes['properties'].apply(
        lambda x: any(
            term in x.get('distinguishedname', '')
            for term in ['TIER 1', 'Tier 1', 'T1']
        )
    ) & (~nodes['id'].isin(tier0_node_ids)) # Add this condition to exclude Tier 0 nodes
]['id'].tolist()

tier2_node_ids = nodes[
    nodes['properties'].apply(
        lambda x: any(
            term in x.get('distinguishedname', '')
            for term in ['TIER 2', 'Tier 2', 'T2']

        )
    ) & (~nodes['id'].isin(tier0_node_ids)) # Add this condition to exclude Tier 0 nodes
]['id'].tolist()

print(f"tier 0 ",len(tier0_node_ids))
# tier1_node_ids = nodes[nodes['properties'].apply(lambda x: 'Tier 1' in x.get('distinguishedname', ''))]['id'].tolist()
print(f"tier 1 ",len(tier1_node_ids))

# tier2_node_ids = nodes[nodes['properties'].apply(lambda x: 'Tier 2' in x.get('distinguishedname', ''))]['id'].tolist()
print(f"tier 2 ",len(tier2_node_ids))
# Out:
# tier 0  265
# tier 1  340
# tier 2  4572

# %%
# Iterate through nodes and add a 'Tier0' column
nodes['Tier0'] = 0  # Initialize 'Tier0' column with 0
nodes['Tier1'] = 0  # Initialize 'Tier0' column with 0
nodes['Tier2'] = 0  # Initialize 'Tier0' column with 0

# Set 'Tier0' to 1 if node id is in tier0_node_ids
nodes.loc[nodes['id'].isin(tier0_node_ids), 'Tier0'] = 1

# Set 'Tier1' to 1 if node id is in tier1_node_ids
nodes.loc[nodes['id'].isin(tier1_node_ids), 'Tier1'] = 1

# Set 'Tier2' to 1 if node id is in tier2_node_ids
nodes.loc[nodes['id'].isin(tier2_node_ids), 'Tier2'] = 1

# Display the updated nodes DataFrame (optional)
# display(nodes.head())
# display(nodes.tail())

# %%
tier0_count = nodes[nodes['Tier0'] == 1].shape[0]
tier1_count = nodes[nodes['Tier1'] == 1].shape[0]
tier2_count = nodes[nodes['Tier2'] == 1].shape[0]

print(f"Number of nodes in Tier 0: {tier0_count}")
print(f"Number of nodes in Tier 1: {tier1_count}")
print(f"Number of nodes in Tier 2: {tier2_count}")
# Out:
# Number of nodes in Tier 0: 265
# Number of nodes in Tier 1: 340
# Number of nodes in Tier 2: 4572

# %%
# import pandas as pd

# len(tier0_node_ids)
# tier0_node_ids = pd.DataFrame(tier0_node_ids)

# %%
for value in tier0_node_ids:
    if value  == new_node_id:
        nodes.loc[nodes['id'] == value, 'weight'] = 100
    else:
        nodes.loc[nodes['id'] == value, 'weight'] = 20

for value in tier1_node_ids:
    nodes.loc[nodes['id'] == value, 'weight'] = 10

for value in tier2_node_ids:
    nodes.loc[nodes['id'] == value, 'weight'] = 5

# %%
 nodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5275 entries, 0 to 5274
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          5275 non-null   int64
#  1   labels      5274 non-null   object
#  2   properties  5275 non-null   object
#  3   type        5275 non-null   object
#  4   start       0 non-null      object
#  5   end         0 non-null      object
#  6   label       0 non-null      object
#  7   l1          5275 non-null   object
#  8   l2          5275 non-null   object
#  9   l3          7 non-null      object
#  10  weight      5275 non-null   int64
#  11  Tier0       5275 non-null   int64
#  12  Tier1       5275 non-null   int64
#  13  Tier2       5275 non-null   int64
# dtypes: int64(5), object(9)
# memory usage: 577.1+ KB

# %%
# edges['source'] = edges['source'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
# edges['target'] = edges['target'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
# edges = edges.drop(columns=['properties']) #, 'id'])
# edges.head()
#edges = edges[:-51]
#edges = edges.drop(columns=['source', 'target', 'weight'])
# edges.head(60)
# edges.tail(58)
# edges[edges['weight'] >= 8]

# %%
edges = edges[:-265]
edges.tail()
# Out:
#           id  source source_node  target target_node          type  \
# 28312  28312    4317       Group    4251          OU  relationship
# 28313  28313    4318       Group    4249          OU  relationship
# 28314  28314    4318       Group    4251          OU  relationship
# 28315  28315    4312       Group    4353          OU  relationship
# 28316  28316    4318       Group    4353          OU  relationship
#
#             label  weight
# 28312  GenericAll       9
# 28313  GenericAll       9
# 28314  GenericAll       9
# 28315  GenericAll       9
# 28316  GenericAll       9

# %%
# prompt: for each value in tier0_node_ids add a new record in edges where start = value and end = new_node_id, label=TIER0,weight=100 id=id+1

# Get the maximum existing edge ID
max_edge_id = edges['id'].max()
max_edge_id
i=1
new_edges = []
for i, tier0_id in enumerate(tier0_node_ids):
    new_edge = {
        'type': 'relationship',  # Assuming type is always 'relationship' for edges
        'source': tier0_id,
        'source_node': 'TIER0',
        'target_node': 'TIER0',
        'target': new_node_id,
        'label': 'TIER0',
        'weight': 100,
        'id': max_edge_id + i + 1 # Assign a unique ID
    }
    new_edges.append(new_edge)

# Convert the list of new edges to a DataFrame
new_edges_df = pd.DataFrame(new_edges)

# Concatenate the new edges DataFrame with the existing edges DataFrame
edges = pd.concat([edges, new_edges_df], ignore_index=True)

# Display the last few rows to confirm the addition
print("Edges DataFrame after adding new TIER0 edges:")
display(edges.tail(266))
# Out:
# Edges DataFrame after adding new TIER0 edges:
#           id  source source_node  target target_node          type  \
# 28316  28316    4318       Group    4353          OU  relationship
# 28317  28317    4252       TIER0    9999       TIER0  relationship
# 28318  28318    4255       TIER0    9999       TIER0  relationship
# 28319  28319    4256       TIER0    9999       TIER0  relationship
# 28320  28320    4257       TIER0    9999       TIER0  relationship
# ...      ...     ...         ...     ...         ...           ...
# 28577  28577    4312       TIER0    9999       TIER0  relationship
# 28578  28578    4317       TIER0    9999       TIER0  relationship
# 28579  28579    4318       TIER0    9999       TIER0  relationship
# 28580  28580    4324       TIER0    9999       TIER0  relationship
# 28581  28581    4398       TIER0    9999       TIER0  relationship
#
#             label  weight
# 28316  GenericAll       9
# 28317       TIER0     100
# 28318       TIER0     100
# 28319       TIER0     100
# 28320       TIER0     100
# ...           ...     ...
# 28577       TIER0     100
# 28578       TIER0     100
# 28579       TIER0     100
# 28580       TIER0     100
# 28581       TIER0     100
#
# [266 rows x 8 columns]

# %%
# Apply the weights based on the 'label' column

def assign_weight(label):
    if label == "GenericAll":
        return 9
    elif label == "Owns":
        return 10
    elif label == "GenericWrite":
        return 2
    elif label == "AllExtendedRights":
        return 6
    elif label == "CanRDP":
        return 2
    elif label == "Contains":
        return 2
    elif label == "DCSync":
        return 8
    elif label == "WriteDacl":
        return 5
    elif label == "WriteOwner":
        return 7
    elif label == "AddKeyCredentialLink":
        return 6
    elif label == "AdminTo":
        return 8
    elif label == "MemberOf":
        return 2
    elif label == "CanPSRemote":
        return 2
    elif label == "ExecuteDCOM":
        return 2
    elif label == "GPLink":
        return 3
    elif label == "HasSession":
        return 9
    elif label == "ReadLAPSPassword":
        return 2
    elif label == "GetChanges":
        return 3
    elif label == "GetChangesAll":
        return 3
    elif label == "AddSelf":
        return 3
    elif label == "ForceChangePassword":
        return 3
    elif label == "AddMember":
        return 5
    elif label == "AllowedToDelegate":
        return 5
    elif label == "AllowedToAct":
        return 4
    elif label == "TIER0":
        return 100
    else:
        return 1 # Default weight for other labels

edges['weight'] = edges['label'].apply(assign_weight)

# Display the updated edges_all DataFrame with the 'weight' column
print("\nEdges_all DataFrame with weight column:")
#edges.head()
#clear_output()
#edges.tail()
# Out:
# Edges_all DataFrame with weight column:

# %%
# prompt: create a unique id for each row, make sure it is of type int64
#edges = edges.drop(columns=['id'])
import numpy as np
#edges['id'] = np.arange(len(edges)).astype('int64')
#edges.head()
edges['id'] = edges['id'].astype('int64')
edges['source'] = edges['source'].astype('int64')
edges['target'] = edges['target'].astype('int64')
edges['weight'] = edges['weight'].astype('int64')
edges.info()
display(edges.head())
display(edges.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28582 entries, 0 to 28581
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           28582 non-null  int64
#  1   source       28582 non-null  int64
#  2   source_node  28582 non-null  object
#  3   target       28582 non-null  int64
#  4   target_node  28582 non-null  object
#  5   type         28582 non-null  object
#  6   label        28582 non-null  object
#  7   weight       28582 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 1.7+ MB
#    id  source source_node  target target_node          type     label  weight
# 0   0    4248      Domain    4249          OU  relationship  Contains       2
# 1   1    4248      Domain    4250          OU  relationship  Contains       2
# 2   2    4248      Domain    4251          OU  relationship  Contains       2
# 3   3    4249          OU    4252          OU  relationship  Contains       2
# 4   4    4249          OU    4253          OU  relationship  Contains       2
#           id  source source_node  target target_node          type  label  \
# 28577  28577    4312       TIER0    9999       TIER0  relationship  TIER0
# 28578  28578    4317       TIER0    9999       TIER0  relationship  TIER0
# 28579  28579    4318       TIER0    9999       TIER0  relationship  TIER0
# 28580  28580    4324       TIER0    9999       TIER0  relationship  TIER0
# 28581  28581    4398       TIER0    9999       TIER0  relationship  TIER0
#
#        weight
# 28577     100
# 28578     100
# 28579     100
# 28580     100
# 28581     100

# %%
selected_edges = edges[(edges['source'].isin(tier2_node_ids))  & (edges['target'].isin(tier0_node_ids)) & (~edges['source'].isin(tier0_node_ids)) & (~edges['target'].isin(tier2_node_ids))]
scratch = selected_edges[selected_edges['weight'] == 8]
scratch(0)

df_max_weight =0
df_max_weight = df_shortest_paths_with_weight['total_weight'].max()
df_max = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == df_max_weight]

# %%
selected_edges_t0 = edges[(edges['source'].isin(tier2_node_ids))  & (edges['target'].isin(tier0_node_ids)) & (~edges['source'].isin(tier0_node_ids)) & (~edges['target'].isin(tier2_node_ids))]
#scratch = selected_edges[selected_edges['weight'] == 8]
print(len(selected_edges_t0))
selected_nodes = nodes[nodes['id'].isin(tier2_node_ids)]
print(len(selected_nodes))
# Out:
# 989
# 4572

# %% [markdown]
# # Dijkstra

# %%
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with their weights
for index, row in selected_nodes.iterrows():
    # Ensure node IDs are integers when adding to the graph
    G.add_node(int(row['id']), weight=row['weight'])

# Add edges with their weights
for index, row in selected_edges_t0.iterrows():
#for index, row in scratch.iterrows():
    # Ensure edge endpoints are integers when adding to the graph
    G.add_edge(row['source'], row['target'], weight=row['weight'])

# Compute shortest paths from each source node to all reachable nodes
shortest_paths = {}
for source in G.nodes():
    # Use single_source_dijkstra_path to find paths from one source to all others
    shortest_paths[source] = nx.single_source_dijkstra_path(G, source)

# Filter out paths from a node to itself and store in a new dictionary
shortest_paths_filtered = {
    source: {
        target: path
        for target, path in paths.items()
        if source != target
        #if target in tier0_node_ids
        #if source in tier2_node_ids
    }
    for source, paths in shortest_paths.items()
}
len(shortest_paths_filtered)

# Print the shortest paths (optional)
# for source, paths in shortest_paths_filtered.items():
#   if paths:
#     #print(f"Shortest paths from node {source}:")
#     for target, path in paths.items():
#         #print(f"  To node {target}: {path}")
#         ShortestPath = source, target, path
#        # print(ShortestPath)
# Out:
# 4730

# %%
tier2_node_ids = pd.DataFrame(tier2_node_ids)
#

# %%
def get_edge_weight(start_node, end_node):
    # Find the corresponding edge in the 'edges' DataFrame
    edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]
    if not edge.empty:
        # Assuming there is only one edge with this start and end for simplicity in path finding
        # If multiple edges exist, you might need to adjust based on which edge is part of the shortest path calculation
        return edge.iloc[0]['weight']

#     if not edge.empty:
# # Return the weight from the resulting DataFrame
#         return edge['weight'].values[0]
#     else:
#         return None

shortest_paths_list = []
for source, paths in shortest_paths_filtered.items():
    if paths:
        for target, path in paths.items():
#            get_edge_weight(source, target)
            shortest_paths_list.append({
                'source': int(source),
                'target': int(target),
                'path': path,
                'weight': get_edge_weight(source, target)
            })

# Convert the list of dictionaries to a DataFrame
#shortest_paths_list = pd.DataFrame(shortest_paths_list)

# #shortest_paths_list.info()
# #short = shortest_paths_list[shortest_paths_list['target'].isin(tier2_node_ids)]
# #short1 = short[~short['source'].isin(tier0_node_ids)]
# #len(short)

# %%
shortest_paths_list = pd.DataFrame(shortest_paths_list)
shortest_paths_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  5 non-null      int64
#  1   target  5 non-null      int64
#  2   path    5 non-null      object
#  3   weight  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
#tier0_node_ids.info()

# %%
display(edges[edges['source'] == 286])
# Out:
# Empty DataFrame
# Columns: [id, source, source_node, target, target_node, type, label, weight]
# Index: []

# %%
# def get_edge_weight(start_node, end_node):
#     # Find the corresponding edge in the 'edges' DataFrame
#     edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]
#     # if not edge.empty:
#     #     # Assuming there is only one edge with this start and end for simplicity in path finding
#     #     # If multiple edges exist, you might need to adjust based on which edge is part of the shortest path calculation
#     return edge.iloc[0]['weight']

# shortest_paths_with_weight = []
# path= [705,60,8,610,457,66,286,40]
# tot_weight = 0
# tot = 0
# i=0
# for i in range(len(path) - 1):
#     start_node = path[i]
#     end_node = path[i + 1]
#     edge_weight = get_edge_weight(start_node, end_node)
#     #edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]
#     #print(edge)
#     tot_weight += edge_weight
#     print(tot_weight)
# start_node = 457; end_node = 457;
# edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]

# %%
import pandas as pd
shortest_paths_list = pd.DataFrame(shortest_paths_list)
#short= shortest_paths_list[shortest_paths_list['source'] isin tier2_node_ids]

#tier2_node_ids = pd.DataFrame(tier2_node_ids)

def get_edge_weight(start_node, end_node):
    # Find the corresponding edge in the 'edges' DataFrame
    edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]
    # if not edge.empty:
    #     # Assuming there is only one edge with this start and end for simplicity in path finding
    #     # If multiple edges exist, you might need to adjust based on which edge is part of the shortest path calculation
    return edge.iloc[0]['weight']

#     if not edge.empty:
# # Return the weight from the resulting DataFrame
#         return edge['weight'].values[0]
#     else:
#         return None

# short = shortest_paths_list[shortest_paths_list['source'].isin(tier2_node_ids)]
# short1 = short[short['target'].isin(tier0_node_ids)]
# len(short1)
# max_value = short1['total_weight'].max()
# max_rows = short1[short1['total_weight'] == max_value]
# len(max_rows)
#df_filtered_paths.loc[df_filtered_paths['total_weight'].idxmin()]

# Calculate the total weight for each shortest path

shortest_paths_with_weight = []

# Iterate through the DataFrame 'short1' using 'iterrows()'
for index, path_info in shortest_paths_list.iterrows():
    total_weight = 0
# The path is expected to be a list of node IDs
    path = path_info['path']
    source = path_info['source']
    target = path_info['target']

# Ensure that 'path' is a list; you may need to adjust this if 'path' is a string
    if isinstance(path, list):
    # Iterate through the path to get the edges
        for i in range(len(path) - 1):
            start_node = path[i]
            end_node = path[i + 1]
        # Assuming you have a way to get the weight of the edge between start_node and end_node
        # For example, if you have a function or a mapping for edge weights
            edge_weight = get_edge_weight(start_node, end_node) # Define this function to retrieve the weight
            total_weight += edge_weight
            shortest_paths_with_weight.append({'source': source, 'target': target, 'path': path, 'total_weight': total_weight})

# Append the result (path and its total weight) to the list
#shortest_paths_with_weight.append({source: source, target: target, path: path, 'total_weight': total_weight})

df1 = pd.DataFrame(shortest_paths_with_weight).copy()
df_shortest_paths_with_weight = df1[(df1['source'].isin(tier2_node_ids)) & (df1['target'].isin(tier0_node_ids))]# & (~df1['source'].isin(tier0_node_ids)) & (~df1['target'].isin(tier2_node_ids))]
#d = df_max[(df_max['source'].isin(tier2_node_ids)) & (df_max['target'].isin(tier0_node_ids)) & (~df_max['source'].isin(tier0_node_ids)) & (~df_max['target'].isin(tier2_node_ids))]
# At this point, shortest_paths_with_weight will contain all paths and their corresponding weights
len(df_shortest_paths_with_weight)
# Out:
# 989

# %%
type(tier2_node_ids)
type(tier2_node_ids[0])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247464 entries, 0 to 247463
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   source        247464 non-null  int64
#  1   target        247464 non-null  int64
#  2   path          247464 non-null  object
#  3   total_weight  247464 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.6+ MB

# %%
# edges = edges.reset_index(drop=True)
# edges.head()

# %%
import networkx as nx
import matplotlib.pyplot as plt


# Example: multiple paths as lists of nodes
#paths = df_min_weight_paths['path']
paths = df_shortest_paths_with_weight['path']
# Create an empty graph
G = nx.DiGraph()

# Add edges from all paths
for path in paths:
# Add edges for consecutive pairs of nodes in the path
    edges_G = list(zip(path[:-1], path[1:]))
    G.add_edges_from(edges_G)

# Draw the graph
pos = nx.spring_layout(G, scale=2,k=0.85, iterations=50) # Layout algorithm for positions
nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500)

# Optionally highlight each path in a different colour
colors = ['red', 'green', 'blue', 'purple']
for path, color in zip(paths, colors):
    edges_zip = list(zip(path[:-1], path[1:]))
    nx.draw_networkx_edges(G, pos, edgelist=edges_zip, edge_color=color, width=2)
#plt.figure(figsize=(12, 8))
plt.title("Multiple Paths in NetworkX Graph")
plt.show()

# %%
len(tier0_node_ids)
# Out:
# 265

# %%
import networkx as nx
import pydot
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import *
# graphviz is installed already, but need lib too
#!apt install libgraphviz-dev
#!pip install pygraphviz
# import pygraphviz as G_pgv

df=df_shortest_paths_with_weight
# df_max1 = []

# df_max1 = df[(df['source'].isin(tier2_node_ids))]# & (df['target'].isin(tier0_node_ids))]

df_max_weight =0
df_max_weight = df_shortest_paths_with_weight['total_weight'].max()
df_max = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == df_max_weight]
#d = df_max[(df_max['source'].isin(tier2_node_ids)) & (df_max['target'].isin(tier0_node_ids)) & (~df_max['source'].isin(tier0_node_ids)) & (~df_max['target'].isin(tier2_node_ids))]

#df.columns = ["source", "target", "path", "weight"]
#sample = df.sample(500, random_state = 1)
#sample.head(10)

G = nx.DiGraph()
#graph [root=new_node_id label=twopi]

for index, row in df_max.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight']

    # Add nodes for all nodes in the path
    for node in path:
        G.add_node(str(node))

    # Add edges for consecutive nodes in the path
    for i in range(len(path) - 1):
        G.add_edge(str(path[i]), str(path[i+1]))
colors = []
#Assuming node 4 is the one to highlight
for node in G.nodes():
    if int(node) in tier0_node_ids:
    #== new_node_id : # Ensure comparison is with string if nodes are strings
        colors.append('red')
        height=6
    elif int(node) in tier1_node_ids:
        colors.append('orange')
        height=4
    elif int(node) in tier2_node_ids:
        colors.append('green')
        height=2
    else:
        colors.append('yellow')

# Set graph attributes to control spacing
# G.graph['ranksep'] = '1.0' # Increase separation between ranks
# G.graph['nodesep'] = '4.0' # Increase separation between nodes

#G_pgv.graph_attr.update(root=new_node_id,ranksep='3.0',nodesep='2.0')
#G_pgv.draw('pytry.jpg',prog='twopi') # This line caused the error
plt.figure(figsize=(12, 12))
# Use pydot_layout with 'twopi' program
pos = pydot_layout(G, prog="twopi")#, root=str(new_node_id)) # Removed root as it might not exist in the graph
nx.draw(G, pos, node_color=colors, with_labels=True, node_size=750, font_weight='normal')

plt.title("Graph Visualization with Twopi Layout")
graph_name_max = suf + '_max_twopi_graph.pdf'
plt.savefig(graph_name_max, format="pdf")
plt.show()

# %%
print(nodes[nodes['id'] == 3167])
print(nodes[nodes['id'] == 3366])
# print(nodes[nodes['id'] == 6452])
# print(nodes[nodes['id'] == 6433])
# print(nodes[nodes['id'] == 6534])
# print(nodes[nodes['id'] == 6458])
# print(nodes[nodes['id'] == 6433])
# Out:
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []

# %%
import networkx as nx
import pydot
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import *
# graphviz is installed already, but need lib too
#!apt install libgraphviz-dev
#!pip install pygraphviz
# import pygraphviz as G_pgv

df=df_shortest_paths_with_weight

df_min_weight =2
#df_min_weight = df_shortest_paths_with_weight['total_weight'].min()
df_min = df[(df['total_weight'] == df_min_weight) & (df['target'].isin(tier0_node_ids))]



G = nx.DiGraph()
#graph [root=new_node_id label=twopi]

for index, row in df_min.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight']

    # Add nodes for all nodes in the path
    for node in path:
        G.add_node(str(node))

    # Add edges for consecutive nodes in the path
    for i in range(len(path) - 1):
        G.add_edge(str(path[i]), str(path[i+1]))
colors = []
#Assuming node 4 is the one to highlight
for node in G.nodes():
    if int(node) in tier0_node_ids:
    #== new_node_id : # Ensure comparison is with string if nodes are strings
        colors.append('red')
        height=6
    elif int(node) in tier1_node_ids:
        colors.append('orange')
        height=4
    elif int(node) in tier2_node_ids:
        colors.append('green')
        height=2
    else:
        colors.append('yellow')

# Set graph attributes to control spacing
G.graph['ranksep'] = '2.0' # Increase separation between ranks
G.graph['nodesep'] = '3.0' # Increase separation between nodes

#G_pgv.graph_attr.update(root=new_node_id,ranksep='3.0',nodesep='2.0')
#G_pgv.draw('pytry.jpg',prog='twopi') # This line caused the error
plt.figure(figsize=(12, 12))
# Use pydot_layout with 'twopi' program
pos = pydot_layout(G, prog="twopi", root=str(new_node_id)) # Removed root as it might not exist in the graph
nx.draw(G, pos, node_color=colors, with_labels=True, node_size=650, font_weight='normal')

plt.title("Graph Visualization with Twopi Layout")
graph_name = suf + '_min_twopi_graph.pdf'
plt.savefig(graph_name, format="pdf")
plt.show()

# %%
print(nodes[nodes['id'] == 3167])
print(nodes[nodes['id'] == 3366])
# print(nodes[nodes['id'] == 6452])
# print(nodes[nodes['id'] == 6433])
# print(nodes[nodes['id'] == 6534])
# print(nodes[nodes['id'] == 6458])
# print(nodes[nodes['id'] == 6433])
# Out:
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []

# %%
# admin_nodes = nodes[
#     nodes['properties'].apply(
#         lambda x: isinstance(x, dict) and 'name' in x and 'administrator' in x['name'].lower()
#     )
# ]
# display(admin_nodes)

# %%
edges.head()
# Out:
#    id  source source_node  target target_node          type     label  weight
# 0   0    4248      Domain    4249          OU  relationship  Contains       2
# 1   1    4248      Domain    4250          OU  relationship  Contains       2
# 2   2    4248      Domain    4251          OU  relationship  Contains       2
# 3   3    4249          OU    4252          OU  relationship  Contains       2
# 4   4    4249          OU    4253          OU  relationship  Contains       2

# %%
df_shortest_paths_with_weight.info()


tier2_node_ids = [int(node_id) for node_id in tier2_node_ids]
print(f"Type of elements in tier2_node_ids after conversion: {type(tier2_node_ids[0]) if tier2_node_ids else 'List is empty'}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   source        0 non-null      int64
#  1   target        0 non-null      int64
#  2   path          0 non-null      object
#  3   total_weight  0 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 0.0+ bytes
# Type of elements in tier2_node_ids after conversion: <class 'int'>

# %%
import pandas as pd
from pyvis.network import Network
#pyvis.__version__

#Loading the data
#data = pd.read_csv("facebook_combined.txt", sep=" ", header=None)
df=df_shortest_paths_with_weight


df_min_weight =2
#df_min_weight = df_shortest_paths_with_weight['total_weight'].min()
df_min = df[(df['total_weight'] == df_min_weight) & (df['target'].isin(tier0_node_ids))]

net = Network(notebook = True, cdn_resources = "in_line",
                bgcolor = "#222222",
                font_color = "white",
                height = "750px",
                width = "100%",
                directed=True
)
net.repulsion()
for index, row in df_min.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight'] # Changed 'total_weight' to 'weight'

    # Add nodes for all nodes in the path
    for node in path:
      if node in tier0_node_ids:
        net.add_node(str(node), label=str(node), color='red') # Added label for better visualization
      else:
        net.add_node(str(node), label=str(node), color='green')

    # Add edges for consecutive pairs of nodes in the path
    for i in range(len(path) - 1):
        net.add_edge(str(path[i]), str(path[i+1]), weight=weight, title=f"Weight: {weight}") # Added weight and title to edge
#suf="vul1k"
graph_name = suf + '_min_graph.html'
net.show(graph_name)
# Out:
# vul5k_min_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="vul5k_min_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df_max_weight =0
df_max_weight = df_shortest_paths_with_weight['total_weight'].max()
df_max = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == df_max_weight]







#df.columns = ["source", "target", "path", "weight"]
#sample = df.sample(500, random_state = 1)
#sample.head(10)

net = Network(notebook = True, cdn_resources = "in_line",
                bgcolor = "#222222",
                font_color = "white",
                height = "750px",
                width = "100%",
                directed=True
)
net.repulsion()

for index, row in df_max.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight'] # Changed 'total_weight' to 'weight'

    # Add nodes for all nodes in the path
    for node in path:
      if node in tier0_node_ids:
        net.add_node(str(node), label=str(node), color='red') # Added label for better visualization
      elif node in tier1_node_ids:
        net.add_node(str(node), label=str(node), color='orange')
      elif node in tier2_node_ids:
        net.add_node(str(node), label=str(node), color='green')
      else:
        net.add_node(str(node), label=str(node), color='yellow')

    # Add edges for consecutive pairs of nodes in the path
    for i in range(len(path) - 1):
        net.add_edge(str(path[i]), str(path[i+1]), weight=weight, title=f"Weight: {weight}") # Added weight and title to edge
graph_name = suf + '_max_graph.html'
net.show(graph_name)
# Out:
# vul5k_max_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="vul5k_max_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
for index, row in df_max.iterrows():
    path = row['path']
    print(f"Path: {path}")
    for node_id in path:
        # Find the node in the nodes DataFrame
        node_info = nodes[nodes['id'] == node_id]
        if not node_info.empty:
            # Get the properties and check for 'name' and Tier information
            properties = node_info.iloc[0]['properties']
            node_name = properties.get('name', 'N/A')
            is_tier0 = node_info.iloc[0]['Tier0'] == 1
            is_tier1 = node_info.iloc[0]['Tier1'] == 1
            is_tier2 = node_info.iloc[0]['Tier2'] == 1
            print(f"  Node ID: {node_id}, Name: {node_name}, Tier0: {is_tier0}, Tier1: {is_tier1}, Tier2: {is_tier2}")
        else:
            print(f"  Node ID: {node_id} not found in nodes DataFrame.")
    print("-" * 20)
# Out:
# Path: [6203, 4516]
#   Node ID: 6203, Name: PAW-00002@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4516, Name: VHOAGBERG00119@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6204, 4467]
#   Node ID: 6204, Name: S-00001@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4467, Name: JPEETERS00068@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6211, 4335]
#   Node ID: 6211, Name: WS-00002@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4335, Name: MTREOLA00092@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6217, 4552]
#   Node ID: 6217, Name: S-00006@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4552, Name: EZANDERIGO00155@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6217, 4434]
#   Node ID: 6217, Name: S-00006@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4434, Name: JHORDGE00035@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6221, 5658]
#   Node ID: 6221, Name: WS-00005@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5658, Name: WDUFAULT01261@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6221, 4456]
#   Node ID: 6221, Name: WS-00005@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4456, Name: CSULLIVAN00057@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6224, 5481]
#   Node ID: 6224, Name: WS-00006@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5481, Name: JMOURET01084@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6227, 4765]
#   Node ID: 6227, Name: WS-00007@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4765, Name: MWHITTIER00368@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6230, 5373]
#   Node ID: 6230, Name: WS-00009@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5373, Name: SSHACKETT00976@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6231, 5732]
#   Node ID: 6231, Name: WS-00010@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5732, Name: ZMCDERMOTT01335@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6231, 4553]
#   Node ID: 6231, Name: WS-00010@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4553, Name: RCASH00156@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6232, 5967]
#   Node ID: 6232, Name: WS-00011@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5967, Name: RCOWETT01570@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6233, 4434]
#   Node ID: 6233, Name: WS-00012@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4434, Name: JHORDGE00035@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6236, 4536]
#   Node ID: 6236, Name: PAW-00011@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4536, Name: SSIEMERING00139@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6245, 5945]
#   Node ID: 6245, Name: WS-00015@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6248, 5131]
#   Node ID: 6248, Name: WS-00016@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5131, Name: RVANDERNOOT00734@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6250, 5732]
#   Node ID: 6250, Name: WS-00018@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5732, Name: ZMCDERMOTT01335@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6251, 5328]
#   Node ID: 6251, Name: WS-00019@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5328, Name: DREFFITT00931@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6260, 5322]
#   Node ID: 6260, Name: WS-00021@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5322, Name: JJOURNOT00925@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6263, 4535]
#   Node ID: 6263, Name: WS-00024@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4535, Name: MAIRINGTON00138@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6266, 4558]
#   Node ID: 6266, Name: S-00024@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4558, Name: LPICHARD00161@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6271, 4572]
#   Node ID: 6271, Name: WS-00028@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4572, Name: BFINCH00175@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6277, 5967]
#   Node ID: 6277, Name: WS-00031@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5967, Name: RCOWETT01570@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6278, 5945]
#   Node ID: 6278, Name: WS-00032@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6278, 4535]
#   Node ID: 6278, Name: WS-00032@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4535, Name: MAIRINGTON00138@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6281, 5945]
#   Node ID: 6281, Name: WS-00034@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6292, 4857]
#   Node ID: 6292, Name: WS-00042@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4857, Name: WMCDAVITT00460@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6292, 4889]
#   Node ID: 6292, Name: WS-00042@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4889, Name: IMYNATT00492@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6294, 5460]
#   Node ID: 6294, Name: WS-00043@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5460, Name: PMACHT01063@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6299, 4556]
#   Node ID: 6299, Name: S-00031@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4556, Name: TBORRIELLO00159@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6303, 5596]
#   Node ID: 6303, Name: WS-00046@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5596, Name: DCHEBRET01199@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6305, 4479]
#   Node ID: 6305, Name: WS-00047@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4479, Name: HREUST00080@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6305, 4448]
#   Node ID: 6305, Name: WS-00047@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4448, Name: DBROADDUS00049@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6305, 4558]
#   Node ID: 6305, Name: WS-00047@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4558, Name: LPICHARD00161@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6308, 4415]
#   Node ID: 6308, Name: WS-00048@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4415, Name: EDUFF00016@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6314, 4570]
#   Node ID: 6314, Name: S-00034@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4570, Name: ADRINKARD00173@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6319, 4414]
#   Node ID: 6319, Name: WS-00055@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4414, Name: SLAVELLI00015@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6320, 5036]
#   Node ID: 6320, Name: WS-00056@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5036, Name: ANIBERT00639@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6323, 5103]
#   Node ID: 6323, Name: WS-00057@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5103, Name: TDAICHENDT00706@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6325, 6140]
#   Node ID: 6325, Name: WS-00059@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6140, Name: SVANFLEET01743@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6327, 4449]
#   Node ID: 6327, Name: S-00036@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4449, Name: COCANA00050@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6329, 4514]
#   Node ID: 6329, Name: WS-00061@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4514, Name: CKALLBRIER00117@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6329, 4446]
#   Node ID: 6329, Name: WS-00061@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4446, Name: LRADOSLOVICH00047@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6331, 5481]
#   Node ID: 6331, Name: WS-00063@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5481, Name: JMOURET01084@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6331, 4535]
#   Node ID: 6331, Name: WS-00063@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4535, Name: MAIRINGTON00138@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6337, 4808]
#   Node ID: 6337, Name: WS-00065@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4808, Name: DLENORT00411@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6340, 4479]
#   Node ID: 6340, Name: WS-00067@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4479, Name: HREUST00080@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6341, 4420]
#   Node ID: 6341, Name: WS-00068@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4420, Name: EGROSSO00021@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6347, 4857]
#   Node ID: 6347, Name: WS-00073@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4857, Name: WMCDAVITT00460@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6349, 4889]
#   Node ID: 6349, Name: WS-00075@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4889, Name: IMYNATT00492@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6349, 4437]
#   Node ID: 6349, Name: WS-00075@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4437, Name: BROGGENSACK00038@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6351, 4570]
#   Node ID: 6351, Name: WS-00076@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4570, Name: ADRINKARD00173@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6353, 4484]
#   Node ID: 6353, Name: WS-00077@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4484, Name: LMARCO00085@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6357, 5215]
#   Node ID: 6357, Name: WS-00079@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5215, Name: CFOUT00818@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6357, 4473]
#   Node ID: 6357, Name: WS-00079@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4473, Name: TEISERT00074@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6358, 6140]
#   Node ID: 6358, Name: WS-00080@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6140, Name: SVANFLEET01743@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6358, 4534]
#   Node ID: 6358, Name: WS-00080@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4534, Name: DSALDI00137@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6361, 6020]
#   Node ID: 6361, Name: WS-00081@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6020, Name: CLUST01623@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6366, 5184]
#   Node ID: 6366, Name: WS-00084@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5184, Name: RLAMONT00787@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6375, 4452]
#   Node ID: 6375, Name: WS-00088@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4452, Name: FLOCKLEY00053@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6376, 5649]
#   Node ID: 6376, Name: WS-00089@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5649, Name: RTENNETT01252@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6376, 4534]
#   Node ID: 6376, Name: WS-00089@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4534, Name: DSALDI00137@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6381, 5732]
#   Node ID: 6381, Name: WS-00093@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5732, Name: ZMCDERMOTT01335@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6381, 4570]
#   Node ID: 6381, Name: WS-00093@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4570, Name: ADRINKARD00173@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6388, 4476]
#   Node ID: 6388, Name: WS-00098@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4476, Name: LCASTROVINCI00077@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6389, 4541]
#   Node ID: 6389, Name: WS-00099@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4541, Name: JLOFASO00144@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6389, 4335]
#   Node ID: 6389, Name: WS-00099@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4335, Name: MTREOLA00092@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6390, 6118]
#   Node ID: 6390, Name: WS-00100@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6118, Name: OHARGEST01721@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6391, 4420]
#   Node ID: 6391, Name: S-00047@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4420, Name: EGROSSO00021@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6394, 4406]
#   Node ID: 6394, Name: S-00048@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4406, Name: MLAURITA00007@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6394, 4442]
#   Node ID: 6394, Name: S-00048@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4442, Name: LNETTE00043@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6400, 5358]
#   Node ID: 6400, Name: WS-00106@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5358, Name: PSPILLETT00961@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6401, 5036]
#   Node ID: 6401, Name: WS-00107@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5036, Name: ANIBERT00639@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6402, 4481]
#   Node ID: 6402, Name: WS-00108@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4481, Name: LMAZZANTI00082@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6405, 5121]
#   Node ID: 6405, Name: WS-00109@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5121, Name: DPARAT00724@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6405, 5305]
#   Node ID: 6405, Name: WS-00109@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5305, Name: IGRISSET00908@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6407, 5260]
#   Node ID: 6407, Name: WS-00110@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5260, Name: MBARTLET00863@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6409, 4405]
#   Node ID: 6409, Name: WS-00111@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6409, 4504]
#   Node ID: 6409, Name: WS-00111@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4504, Name: LHIEFNAR00107@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6410, 5215]
#   Node ID: 6410, Name: WS-00112@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5215, Name: CFOUT00818@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6412, 4489]
#   Node ID: 6412, Name: WS-00113@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4489, Name: FTAMES00090@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6420, 4570]
#   Node ID: 6420, Name: WS-00117@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4570, Name: ADRINKARD00173@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6425, 5131]
#   Node ID: 6425, Name: WS-00120@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5131, Name: RVANDERNOOT00734@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6425, 5171]
#   Node ID: 6425, Name: WS-00120@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5171, Name: OBOSHART00774@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6429, 5237]
#   Node ID: 6429, Name: WS-00122@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5237, Name: MBLEWITT00840@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6431, 4449]
#   Node ID: 6431, Name: S-00058@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4449, Name: COCANA00050@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6438, 6120]
#   Node ID: 6438, Name: WS-00126@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6120, Name: GLACHUT01723@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6440, 4467]
#   Node ID: 6440, Name: WS-00127@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4467, Name: JPEETERS00068@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6441, 5732]
#   Node ID: 6441, Name: WS-00128@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5732, Name: ZMCDERMOTT01335@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6448, 5694]
#   Node ID: 6448, Name: WS-00132@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5694, Name: LTRUETT01297@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6455, 4808]
#   Node ID: 6455, Name: WS-00135@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4808, Name: DLENORT00411@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6455, 5713]
#   Node ID: 6455, Name: WS-00135@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5713, Name: HDOUTHIT01316@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6457, 5358]
#   Node ID: 6457, Name: WS-00136@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5358, Name: PSPILLETT00961@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6460, 4479]
#   Node ID: 6460, Name: WS-00138@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4479, Name: HREUST00080@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6460, 4420]
#   Node ID: 6460, Name: WS-00138@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4420, Name: EGROSSO00021@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6462, 4479]
#   Node ID: 6462, Name: WS-00139@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4479, Name: HREUST00080@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6464, 5596]
#   Node ID: 6464, Name: WS-00141@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5596, Name: DCHEBRET01199@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6468, 5305]
#   Node ID: 6468, Name: WS-00142@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5305, Name: IGRISSET00908@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6468, 5945]
#   Node ID: 6468, Name: WS-00142@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6471, 4556]
#   Node ID: 6471, Name: WS-00144@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4556, Name: TBORRIELLO00159@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6477, 5828]
#   Node ID: 6477, Name: WS-00147@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5828, Name: MNOLET01431@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6477, 4473]
#   Node ID: 6477, Name: WS-00147@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4473, Name: TEISERT00074@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6478, 4406]
#   Node ID: 6478, Name: WS-00148@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4406, Name: MLAURITA00007@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6484, 4406]
#   Node ID: 6484, Name: S-00071@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4406, Name: MLAURITA00007@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6484, 4481]
#   Node ID: 6484, Name: S-00071@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4481, Name: LMAZZANTI00082@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6488, 4857]
#   Node ID: 6488, Name: WS-00151@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4857, Name: WMCDAVITT00460@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6488, 5121]
#   Node ID: 6488, Name: WS-00151@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5121, Name: DPARAT00724@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6491, 6124]
#   Node ID: 6491, Name: WS-00154@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6124, Name: GQUANDT01727@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6494, 4414]
#   Node ID: 6494, Name: WS-00157@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4414, Name: SLAVELLI00015@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6496, 4408]
#   Node ID: 6496, Name: S-00073@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4408, Name: GVANVICKLE00009@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6496, 4446]
#   Node ID: 6496, Name: S-00073@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4446, Name: LRADOSLOVICH00047@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6497, 4679]
#   Node ID: 6497, Name: WS-00159@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4679, Name: CMESSERSCHMIDT00282@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6500, 4496]
#   Node ID: 6500, Name: S-00075@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4496, Name: JROOP00099@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6501, 6120]
#   Node ID: 6501, Name: S-00076@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6120, Name: GLACHUT01723@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6502, 4568]
#   Node ID: 6502, Name: WS-00161@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4568, Name: MEWIG00171@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6504, 5358]
#   Node ID: 6504, Name: S-00077@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5358, Name: PSPILLETT00961@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6506, 4711]
#   Node ID: 6506, Name: WS-00164@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4711, Name: AMOYET00314@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6513, 4446]
#   Node ID: 6513, Name: WS-00168@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4446, Name: LRADOSLOVICH00047@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6515, 4405]
#   Node ID: 6515, Name: WS-00170@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6517, 4765]
#   Node ID: 6517, Name: S-00081@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4765, Name: MWHITTIER00368@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6517, 4557]
#   Node ID: 6517, Name: S-00081@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4557, Name: TREMY00160@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6517, 4489]
#   Node ID: 6517, Name: S-00081@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4489, Name: FTAMES00090@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6518, 5967]
#   Node ID: 6518, Name: WS-00172@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5967, Name: RCOWETT01570@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6519, 5373]
#   Node ID: 6519, Name: WS-00173@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5373, Name: SSHACKETT00976@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6524, 5713]
#   Node ID: 6524, Name: WS-00175@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5713, Name: HDOUTHIT01316@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6524, 5731]
#   Node ID: 6524, Name: WS-00175@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5731, Name: KHIETT01334@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6526, 7804]
#   Node ID: 6526, Name: WS-00177@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 7804, Name: T0 DEFAULT ADMIN USER@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6528, 4929]
#   Node ID: 6528, Name: WS-00179@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4929, Name: LCALICUTT00532@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6528, 5264]
#   Node ID: 6528, Name: WS-00179@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5264, Name: AAHLQUIST00867@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6528, 4405]
#   Node ID: 6528, Name: WS-00179@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6529, 4510]
#   Node ID: 6529, Name: WS-00180@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4510, Name: SBIBEE00113@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6532, 5358]
#   Node ID: 6532, Name: WS-00183@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5358, Name: PSPILLETT00961@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6534, 5009]
#   Node ID: 6534, Name: WS-00184@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5009, Name: VGLADHART00612@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6534, 5527]
#   Node ID: 6534, Name: WS-00184@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5527, Name: SFOGELQUIST01130@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6538, 5194]
#   Node ID: 6538, Name: WS-00187@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5194, Name: DSEIBERT00797@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6538, 5305]
#   Node ID: 6538, Name: WS-00187@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5305, Name: IGRISSET00908@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6538, 4479]
#   Node ID: 6538, Name: WS-00187@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4479, Name: HREUST00080@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6542, 4649]
#   Node ID: 6542, Name: WS-00190@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4649, Name: DGRILLOT00252@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6543, 6020]
#   Node ID: 6543, Name: WS-00191@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6020, Name: CLUST01623@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6543, 4405]
#   Node ID: 6543, Name: WS-00191@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6543, 4556]
#   Node ID: 6543, Name: WS-00191@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4556, Name: TBORRIELLO00159@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6552, 5460]
#   Node ID: 6552, Name: WS-00195@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5460, Name: PMACHT01063@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6553, 5358]
#   Node ID: 6553, Name: WS-00196@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5358, Name: PSPILLETT00961@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6557, 4411]
#   Node ID: 6557, Name: WS-00198@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4411, Name: YROADEN00012@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6560, 4983]
#   Node ID: 6560, Name: WS-00200@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4983, Name: DKNOCKAERT00586@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6562, 4512]
#   Node ID: 6562, Name: WS-00202@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4512, Name: YLARRIUZ00115@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6563, 5649]
#   Node ID: 6563, Name: WS-00203@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5649, Name: RTENNETT01252@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6570, 5623]
#   Node ID: 6570, Name: WS-00208@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5623, Name: TGARROTT01226@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6570, 4536]
#   Node ID: 6570, Name: WS-00208@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4536, Name: SSIEMERING00139@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6572, 5372]
#   Node ID: 6572, Name: S-00092@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5372, Name: HGILLETT00975@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6572, 4467]
#   Node ID: 6572, Name: S-00092@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4467, Name: JPEETERS00068@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6575, 5727]
#   Node ID: 6575, Name: WS-00210@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5727, Name: CGENNETT01330@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6576, 4448]
#   Node ID: 6576, Name: WS-00211@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4448, Name: DBROADDUS00049@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6578, 4405]
#   Node ID: 6578, Name: PAW-00072@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6590, 5372]
#   Node ID: 6590, Name: WS-00217@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5372, Name: HGILLETT00975@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6591, 5481]
#   Node ID: 6591, Name: WS-00218@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5481, Name: JMOURET01084@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6592, 5460]
#   Node ID: 6592, Name: WS-00219@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5460, Name: PMACHT01063@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6593, 5131]
#   Node ID: 6593, Name: WS-00220@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5131, Name: RVANDERNOOT00734@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6596, 5009]
#   Node ID: 6596, Name: WS-00222@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5009, Name: VGLADHART00612@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6596, 6120]
#   Node ID: 6596, Name: WS-00222@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6120, Name: GLACHUT01723@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6601, 4631]
#   Node ID: 6601, Name: WS-00226@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4631, Name: EGIRARDOT00234@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6601, 4467]
#   Node ID: 6601, Name: WS-00226@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4467, Name: JPEETERS00068@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6606, 4479]
#   Node ID: 6606, Name: WS-00229@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4479, Name: HREUST00080@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6608, 5372]
#   Node ID: 6608, Name: WS-00231@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5372, Name: HGILLETT00975@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6608, 6140]
#   Node ID: 6608, Name: WS-00231@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6140, Name: SVANFLEET01743@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6608, 4405]
#   Node ID: 6608, Name: WS-00231@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6610, 5714]
#   Node ID: 6610, Name: WS-00232@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5714, Name: KGASSERT01317@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6613, 4512]
#   Node ID: 6613, Name: PAW-00079@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4512, Name: YLARRIUZ00115@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6614, 4335]
#   Node ID: 6614, Name: WS-00235@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4335, Name: MTREOLA00092@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6616, 5731]
#   Node ID: 6616, Name: WS-00236@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5731, Name: KHIETT01334@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6618, 4828]
#   Node ID: 6618, Name: WS-00237@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4828, Name: ACHERANICHIT00431@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6623, 5945]
#   Node ID: 6623, Name: WS-00240@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6624, 5915]
#   Node ID: 6624, Name: WS-00241@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5915, Name: PPELCHAT01518@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6627, 4552]
#   Node ID: 6627, Name: WS-00243@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4552, Name: EZANDERIGO00155@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6634, 4534]
#   Node ID: 6634, Name: WS-00248@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4534, Name: DSALDI00137@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6634, 4414]
#   Node ID: 6634, Name: WS-00248@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4414, Name: SLAVELLI00015@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6637, 4446]
#   Node ID: 6637, Name: PAW-00084@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4446, Name: LRADOSLOVICH00047@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6639, 5658]
#   Node ID: 6639, Name: WS-00251@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5658, Name: WDUFAULT01261@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6640, 5036]
#   Node ID: 6640, Name: WS-00252@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5036, Name: ANIBERT00639@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6641, 4442]
#   Node ID: 6641, Name: WS-00253@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4442, Name: LNETTE00043@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6645, 4711]
#   Node ID: 6645, Name: WS-00255@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4711, Name: AMOYET00314@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6647, 4440]
#   Node ID: 6647, Name: PAW-00086@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4440, Name: MROSIN00041@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6648, 5697]
#   Node ID: 6648, Name: S-00106@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5697, Name: MGODBOUT01300@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6650, 5828]
#   Node ID: 6650, Name: WS-00257@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5828, Name: MNOLET01431@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6650, 4411]
#   Node ID: 6650, Name: WS-00257@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4411, Name: YROADEN00012@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6655, 4556]
#   Node ID: 6655, Name: WS-00261@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4556, Name: TBORRIELLO00159@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6656, 5481]
#   Node ID: 6656, Name: WS-00262@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5481, Name: JMOURET01084@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6656, 5527]
#   Node ID: 6656, Name: WS-00262@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5527, Name: SFOGELQUIST01130@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6659, 5171]
#   Node ID: 6659, Name: WS-00263@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5171, Name: OBOSHART00774@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6660, 5527]
#   Node ID: 6660, Name: WS-00264@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5527, Name: SFOGELQUIST01130@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6664, 4448]
#   Node ID: 6664, Name: WS-00267@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4448, Name: DBROADDUS00049@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6667, 5030]
#   Node ID: 6667, Name: WS-00269@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5030, Name: SELLIFRITT00633@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6667, 4559]
#   Node ID: 6667, Name: WS-00269@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4559, Name: TSHREWSBERRY00162@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6668, 4411]
#   Node ID: 6668, Name: S-00112@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4411, Name: YROADEN00012@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6672, 4713]
#   Node ID: 6672, Name: WS-00273@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4713, Name: MDONKERVOET00316@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6675, 4496]
#   Node ID: 6675, Name: WS-00275@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4496, Name: JROOP00099@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6678, 4435]
#   Node ID: 6678, Name: S-00113@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4435, Name: SKLUKKEN00036@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6679, 4541]
#   Node ID: 6679, Name: S-00114@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4541, Name: JLOFASO00144@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6680, 4434]
#   Node ID: 6680, Name: WS-00277@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4434, Name: JHORDGE00035@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6681, 6118]
#   Node ID: 6681, Name: WS-00278@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6118, Name: OHARGEST01721@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6681, 4541]
#   Node ID: 6681, Name: WS-00278@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4541, Name: JLOFASO00144@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6682, 5309]
#   Node ID: 6682, Name: WS-00279@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5309, Name: KHARNIST00912@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6688, 5881]
#   Node ID: 6688, Name: WS-00282@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5881, Name: BWOHLFAHRT01484@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6688, 4552]
#   Node ID: 6688, Name: WS-00282@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4552, Name: EZANDERIGO00155@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6690, 5945]
#   Node ID: 6690, Name: WS-00284@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6693, 5282]
#   Node ID: 6693, Name: WS-00286@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5282, Name: MBEAUDREAULT00885@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6694, 5194]
#   Node ID: 6694, Name: WS-00287@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5194, Name: DSEIBERT00797@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6694, 4570]
#   Node ID: 6694, Name: WS-00287@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4570, Name: ADRINKARD00173@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6695, 5309]
#   Node ID: 6695, Name: WS-00288@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5309, Name: KHARNIST00912@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6695, 4553]
#   Node ID: 6695, Name: WS-00288@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4553, Name: RCASH00156@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6698, 4572]
#   Node ID: 6698, Name: S-00118@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4572, Name: BFINCH00175@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6698, 4568]
#   Node ID: 6698, Name: S-00118@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4568, Name: MEWIG00171@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6698, 4494]
#   Node ID: 6698, Name: S-00118@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4494, Name: OHOEFER00097@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6702, 4510]
#   Node ID: 6702, Name: S-00119@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4510, Name: SBIBEE00113@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6704, 5481]
#   Node ID: 6704, Name: WS-00292@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5481, Name: JMOURET01084@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6705, 5260]
#   Node ID: 6705, Name: WS-00293@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5260, Name: MBARTLET00863@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [6705, 5309]
# ...
# --------------------
# Path: [7666, 4411]
#   Node ID: 7666, Name: WS-00856@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4411, Name: YROADEN00012@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7670, 4556]
#   Node ID: 7670, Name: WS-00860@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4556, Name: TBORRIELLO00159@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7670, 4405]
#   Node ID: 7670, Name: WS-00860@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7674, 5714]
#   Node ID: 7674, Name: WS-00863@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5714, Name: KGASSERT01317@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7677, 5694]
#   Node ID: 7677, Name: WS-00864@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5694, Name: LTRUETT01297@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7679, 4558]
#   Node ID: 7679, Name: WS-00865@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4558, Name: LPICHARD00161@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7680, 4765]
#   Node ID: 7680, Name: WS-00866@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4765, Name: MWHITTIER00368@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7681, 4474]
#   Node ID: 7681, Name: WS-00867@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4474, Name: MSCHOEMAN00075@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7682, 4405]
#   Node ID: 7682, Name: WS-00868@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7686, 4540]
#   Node ID: 7686, Name: WS-00870@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4540, Name: SVIGNARATH00143@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7686, 4405]
#   Node ID: 7686, Name: WS-00870@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7687, 4552]
#   Node ID: 7687, Name: PAW-00293@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4552, Name: EZANDERIGO00155@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7688, 4808]
#   Node ID: 7688, Name: WS-00871@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4808, Name: DLENORT00411@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7691, 4476]
#   Node ID: 7691, Name: WS-00873@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4476, Name: LCASTROVINCI00077@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7692, 5732]
#   Node ID: 7692, Name: WS-00874@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5732, Name: ZMCDERMOTT01335@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7697, 5305]
#   Node ID: 7697, Name: WS-00878@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5305, Name: IGRISSET00908@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7698, 5623]
#   Node ID: 7698, Name: WS-00879@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5623, Name: TGARROTT01226@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7698, 5731]
#   Node ID: 7698, Name: WS-00879@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5731, Name: KHIETT01334@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7703, 5623]
#   Node ID: 7703, Name: WS-00883@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5623, Name: TGARROTT01226@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7706, 5460]
#   Node ID: 7706, Name: WS-00885@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5460, Name: PMACHT01063@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7706, 5649]
#   Node ID: 7706, Name: WS-00885@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5649, Name: RTENNETT01252@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7709, 4631]
#   Node ID: 7709, Name: WS-00887@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4631, Name: EGIRARDOT00234@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7709, 5309]
#   Node ID: 7709, Name: WS-00887@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5309, Name: KHARNIST00912@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7710, 5260]
#   Node ID: 7710, Name: WS-00888@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5260, Name: MBARTLET00863@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7715, 6140]
#   Node ID: 7715, Name: WS-00891@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6140, Name: SVANFLEET01743@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7716, 4865]
#   Node ID: 7716, Name: WS-00892@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4865, Name: JSEHRT00468@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7718, 4857]
#   Node ID: 7718, Name: WS-00894@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4857, Name: WMCDAVITT00460@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7719, 4828]
#   Node ID: 7719, Name: WS-00895@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4828, Name: ACHERANICHIT00431@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7721, 5305]
#   Node ID: 7721, Name: WS-00896@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5305, Name: IGRISSET00908@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7722, 5856]
#   Node ID: 7722, Name: WS-00897@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5856, Name: EMILBRANDT01459@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7722, 6181]
#   Node ID: 7722, Name: WS-00897@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6181, Name: IJURIST01784@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7723, 6181]
#   Node ID: 7723, Name: WS-00898@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6181, Name: IJURIST01784@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7725, 6120]
#   Node ID: 7725, Name: WS-00899@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6120, Name: GLACHUT01723@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7731, 4572]
#   Node ID: 7731, Name: WS-00904@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4572, Name: BFINCH00175@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7733, 4557]
#   Node ID: 7733, Name: WS-00906@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4557, Name: TREMY00160@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7737, 4406]
#   Node ID: 7737, Name: WS-00909@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4406, Name: MLAURITA00007@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7738, 5305]
#   Node ID: 7738, Name: WS-00910@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5305, Name: IGRISSET00908@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7738, 4335]
#   Node ID: 7738, Name: WS-00910@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4335, Name: MTREOLA00092@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7738, 4516]
#   Node ID: 7738, Name: WS-00910@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4516, Name: VHOAGBERG00119@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7746, 4405]
#   Node ID: 7746, Name: WS-00914@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4405, Name: JWEGHORST00006@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7748, 4558]
#   Node ID: 7748, Name: WS-00915@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4558, Name: LPICHARD00161@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7753, 4481]
#   Node ID: 7753, Name: PAW-00301@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4481, Name: LMAZZANTI00082@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7753, 4556]
#   Node ID: 7753, Name: PAW-00301@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4556, Name: TBORRIELLO00159@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7754, 5237]
#   Node ID: 7754, Name: WS-00918@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5237, Name: MBLEWITT00840@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7755, 5945]
#   Node ID: 7755, Name: WS-00919@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5945, Name: TOPTEYNDT01548@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7759, 4808]
#   Node ID: 7759, Name: WS-00921@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4808, Name: DLENORT00411@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7761, 4446]
#   Node ID: 7761, Name: WS-00922@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4446, Name: LRADOSLOVICH00047@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7763, 5881]
#   Node ID: 7763, Name: WS-00924@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5881, Name: BWOHLFAHRT01484@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7766, 5215]
#   Node ID: 7766, Name: WS-00927@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5215, Name: CFOUT00818@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7766, 5881]
#   Node ID: 7766, Name: WS-00927@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5881, Name: BWOHLFAHRT01484@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7768, 5103]
#   Node ID: 7768, Name: WS-00928@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5103, Name: TDAICHENDT00706@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7768, 4467]
#   Node ID: 7768, Name: WS-00928@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4467, Name: JPEETERS00068@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7769, 4487]
#   Node ID: 7769, Name: WS-00929@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4487, Name: CSELBERT00088@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7771, 5967]
#   Node ID: 7771, Name: WS-00931@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5967, Name: RCOWETT01570@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7773, 4713]
#   Node ID: 7773, Name: WS-00932@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4713, Name: MDONKERVOET00316@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7773, 5856]
#   Node ID: 7773, Name: WS-00932@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5856, Name: EMILBRANDT01459@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7774, 4713]
#   Node ID: 7774, Name: WS-00933@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4713, Name: MDONKERVOET00316@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7774, 6140]
#   Node ID: 7774, Name: WS-00933@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 6140, Name: SVANFLEET01743@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7775, 5840]
#   Node ID: 7775, Name: WS-00934@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5840, Name: MHOLBERT01443@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7778, 5131]
#   Node ID: 7778, Name: WS-00936@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5131, Name: RVANDERNOOT00734@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7781, 4889]
#   Node ID: 7781, Name: WS-00938@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4889, Name: IMYNATT00492@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7784, 5658]
#   Node ID: 7784, Name: WS-00941@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5658, Name: WDUFAULT01261@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7785, 5527]
#   Node ID: 7785, Name: WS-00942@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5527, Name: SFOGELQUIST01130@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7787, 5309]
#   Node ID: 7787, Name: WS-00944@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5309, Name: KHARNIST00912@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7788, 5400]
#   Node ID: 7788, Name: WS-00945@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5400, Name: NNEUGENT01003@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7793, 5005]
#   Node ID: 7793, Name: WS-00950@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5005, Name: TPELLET00608@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7793, 4552]
#   Node ID: 7793, Name: WS-00950@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4552, Name: EZANDERIGO00155@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7793, 4456]
#   Node ID: 7793, Name: WS-00950@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4456, Name: CSULLIVAN00057@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7796, 5194]
#   Node ID: 7796, Name: WS-00952@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5194, Name: DSEIBERT00797@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7796, 5649]
#   Node ID: 7796, Name: WS-00952@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5649, Name: RTENNETT01252@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7796, 4451]
#   Node ID: 7796, Name: WS-00952@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 4451, Name: OTEAHAN00052@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------
# Path: [7797, 5171]
#   Node ID: 7797, Name: WS-00953@TESTLAB.LOCALE, Tier0: False, Tier1: False, Tier2: True
#   Node ID: 5171, Name: OBOSHART00774@TESTLAB.LOCALE, Tier0: True, Tier1: False, Tier2: False
# --------------------

# %%
filtered_shortest_paths = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == 1]
display(filtered_shortest_paths)
# Out:
# Empty DataFrame
# Columns: [source, target, path, total_weight]
# Index: []

# %%
# Create a list to store the data for the table
table_data = []

# Iterate through the paths in df_max
for index, row in df_max.iterrows():
    path = row['path']
    # path_str = " -> ".join(map(str, path)) # Convert the path list to a string

    # Iterate through the nodes in the current path
    for node_id in path:
        # Find the node in the nodes DataFrame
        node_info = nodes[nodes['id'] == node_id]
        if not node_info.empty:
            properties = node_info.iloc[0]['properties']
            node_name = properties.get('name', 'N/A')
            is_tier0 = 1 if node_info.iloc[0]['Tier0'] == 1 else 0
            is_tier1 = 1 if node_info.iloc[0]['Tier1'] == 1 else 0
            is_tier2 = 1 if node_info.iloc[0]['Tier2'] == 1 else 0

            # Append the data as a dictionary to the list
            table_data.append({
                'Node Id': node_id, # Changed 'path' to 'Node Id' and stored node_id
                'Name': node_name,
                'Tier 0': is_tier0,
                'Tier 1': is_tier1,
                'Tier 2': is_tier2
            })

# Create a pandas DataFrame from the list of dictionaries
df_path_info = pd.DataFrame(table_data)

# Display the DataFrame
display(df_path_info)
# Out:
#       Node Id                           Name  Tier 0  Tier 1  Tier 2
# 0        6203       PAW-00002@TESTLAB.LOCALE       0       0       1
# 1        4516  VHOAGBERG00119@TESTLAB.LOCALE       1       0       0
# 2        6204         S-00001@TESTLAB.LOCALE       0       0       1
# 3        4467   JPEETERS00068@TESTLAB.LOCALE       1       0       0
# 4        6211        WS-00002@TESTLAB.LOCALE       0       0       1
# ...       ...                            ...     ...     ...     ...
# 1351     5649   RTENNETT01252@TESTLAB.LOCALE       1       0       0
# 1352     7796        WS-00952@TESTLAB.LOCALE       0       0       1
# 1353     4451    OTEAHAN00052@TESTLAB.LOCALE       1       0       0
# 1354     7797        WS-00953@TESTLAB.LOCALE       0       0       1
# 1355     5171   OBOSHART00774@TESTLAB.LOCALE       1       0       0
#
# [1356 rows x 5 columns]

# %%
latex_table = df_path_info.to_latex(index=False)

file_name = suf + "_max_paths_table.tex"

with open(file_name, 'w') as f:
    f.write(latex_table)

print(f"Table exported to {file_name}")
# Out:
# Table exported to 5k_max_paths_table.tex

# %%
count_weight_2 = selected_edges[selected_edges['weight'] == 2].shape[0]
print(f"Number of records in selected_edges with weight == 2: {count_weight_2}")
# Out:
# Number of records in selected_edges with weight == 2: 304

# %%
weight_distribution = selected_edges['weight'].value_counts().sort_index()
print("Distribution of weights in selected_edges:")
print(weight_distribution)
# Out:
# Distribution of weights in selected_edges:
# weight
# 2    304
# 4      1
# 5      1
# 8      5
# 9    678
# Name: count, dtype: int64

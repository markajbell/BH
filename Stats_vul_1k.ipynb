# %% [markdown]
# <a href="https://colab.research.google.com/github/markajbell/BH/blob/main/Stats_vul_1k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !pip install pyvis

import pandas as pd
import numpy as np
import json
import os
import glob
import re
from collections import Counter
# Out:
# Requirement already satisfied: pyvis in /usr/local/lib/python3.11/dist-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis) (3.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9.6->pyvis) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.13)

# %%
pd.set_option('display.max_rows', None)
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
# !wget https://raw.githubusercontent.com/markajbell/BH/refs/heads/main/adsync/vul1k.json

if not os.path.exists('/content/adsync'):
    os.makedirs('/content/adsync')
    print("/content/adsync directory created.")
else:
    print("/content/adsync directory already exists.")

path = "/content/adsync"

# !mv vul1k.json /content/adsync



data = {}
json_files = glob.glob(os.path.join(path, "*.json"))
for file in json_files:
    filename = os.path.basename(file).replace(".json", "")
    suf = filename.split("_")[-1]

    with open(file, 'r', encoding='utf-8') as f:
        content = json.load(f)

    if "data" in content:
        if suf in data:
            data[f"{suf}"].extend(content["data"])
            #print(f" The key 'data' was found in {f}.")
        else:
            data[f"{suf}"] = content["data"]
            #print(f" The key 'data' was found in {f}.")
    else:
        print(f"Warning: The key 'data' was not found in {f}.")
# Out:
# --2025-08-04 16:21:05--  https://raw.githubusercontent.com/markajbell/BH/refs/heads/main/adsync/vul1k.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1915307 (1.8M) [text/plain]
# Saving to: ‘vul1k.json’
#
# vul1k.json          100%[===================>]   1.83M  --.-KB/s    in 0.07s
#
# 2025-08-04 16:21:05 (27.1 MB/s) - ‘vul1k.json’ saved [1915307/1915307]
#
# /content/adsync directory created.

# %%
# prompt: if the type column = "node" save that record into a pandas dataframe called nodes, if the type = "relationship' then save to a pandas dataframe called edges


df = pd.DataFrame(data[suf])
nodes = df[df['type'] == 'node'].copy()
edges = df[df['type'] == 'relationship'].copy()
nodes['id'] = nodes['id'].astype(int)

# %%
# prompt: for every record in "nodes" create a l1, l2 and l3 column for the values in "nodes.labels" eg. for record 1 l1=Base, l2=OU and l3 would be null

import pandas as pd
def extract_labels(labels):
    # Ensure labels is a list
    if not isinstance(labels, list):
        return [None, None, None]

    l1 = labels[0] if len(labels) > 0 else None
    l2 = labels[1] if len(labels) > 1 else None
    l3 = labels[2] if len(labels) > 2 else None
    return [l1, l2, l3]

# Apply the function to create the new columns
nodes[['l1', 'l2', 'l3']] = nodes['labels'].apply(lambda x: pd.Series(extract_labels(x)))

# %%
nodes = nodes.drop(columns=['start', 'end', 'label', 'labels'])
# edges = edges.drop(columns=['labels'])

# %%
edges.head()
# Out:
#        id labels properties          type  \
# 1107  r_0    NaN         {}  relationship
# 1108  r_1    NaN         {}  relationship
# 1109  r_2    NaN         {}  relationship
# 1110  r_3    NaN         {}  relationship
# 1111  r_4    NaN         {}  relationship
#
#                                              start  \
# 1107  {'id': '3141', 'labels': ['Base', 'Domain']}
# 1108  {'id': '3141', 'labels': ['Base', 'Domain']}
# 1109  {'id': '3141', 'labels': ['Base', 'Domain']}
# 1110      {'id': '3142', 'labels': ['Base', 'OU']}
# 1111      {'id': '3142', 'labels': ['Base', 'OU']}
#
#                                            end     label
# 1107  {'id': '3142', 'labels': ['Base', 'OU']}  Contains
# 1108  {'id': '3143', 'labels': ['Base', 'OU']}  Contains
# 1109  {'id': '3144', 'labels': ['Base', 'OU']}  Contains
# 1110  {'id': '3145', 'labels': ['Base', 'OU']}  Contains
# 1111  {'id': '3146', 'labels': ['Base', 'OU']}  Contains

# %%
edges['source'] = edges['start'].apply(lambda x: x.get('id'))
edges['source_node'] = edges['start'].apply(lambda x: x.get('labels')[1] if isinstance(x.get('labels'), list) and len(x.get('labels')) > 1 else None)

edges['target'] = edges['end'].apply(lambda x: x.get('id'))
edges['target_node'] = edges['end'].apply(lambda x: x.get('labels')[1] if isinstance(x.get('labels'), list) and len(x.get('labels')) > 1 else None)

edges = edges.drop(columns=['properties', 'start', 'end', 'id', 'labels'])
edges['id'] = np.arange(len(edges)).astype('int64')
edges = edges.reset_index(drop=True)
nodes['weight'] = 1
edges = edges[['id', 'source', 'source_node', 'target', 'target_node', 'type','label']]
display(edges.head())
edges.info()
# Out:
#    id source source_node target target_node          type     label
# 0   0   3141      Domain   3142          OU  relationship  Contains
# 1   1   3141      Domain   3143          OU  relationship  Contains
# 2   2   3141      Domain   3144          OU  relationship  Contains
# 3   3   3142          OU   3145          OU  relationship  Contains
# 4   4   3142          OU   3146          OU  relationship  Contains
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7081 entries, 0 to 7080
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           7081 non-null   int64
#  1   source       7081 non-null   object
#  2   source_node  7081 non-null   object
#  3   target       7081 non-null   object
#  4   target_node  7081 non-null   object
#  5   type         7081 non-null   object
#  6   label        7081 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 387.4+ KB

# %%
#edges = edges.drop(columns=['id'])
nodes.info()
nodes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1107 entries, 0 to 1106
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1107 non-null   int64
#  1   properties  1107 non-null   object
#  2   type        1107 non-null   object
#  3   l1          1107 non-null   object
#  4   l2          1107 non-null   object
#  5   l3          6 non-null      object
#  6   weight      1107 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 69.2+ KB
#      id  \
# 0  3141
# 1  3142
# 2  3143
# 3  3144
# 4  3145
#
#                                                                                                                                                                                                                                                                                                               properties  \
# 0                                                                                               {'domain': 'TESTLAB.LOCALE', 'name': 'TESTLAB.LOCALE', 'highvalue': True, 'objectid': 'S-1-5-21-883232822-274137685-4173207997', 'distinguishedname': 'DC=TESTLAB,DC=LOCALE', 'functionallevel': '2012', 'owned': False}
# 1                    {'domain': 'TESTLAB.LOCALE', 'name': 'Admin@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-2c47b3e6-4444-4baa-9922-a5d31aeb199d', 'distinguishedname': 'OU=ADMIN,DC=TESTLAB,DC=LOCALE', 'description': None, 'highvalue': False, 'blocksInheritance': False, 'owned': False}
# 2  {'domain': 'TESTLAB.LOCALE', 'name': 'Tier 1 Servers@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-d6e85c70-e8ce-42e2-9cfd-efd073a382e8', 'distinguishedname': 'OU=TIER 1 SERVERS,DC=TESTLAB,DC=LOCALE', 'description': None, 'highvalue': False, 'blocksInheritance': False, 'owned': False}
# 3                  {'domain': 'TESTLAB.LOCALE', 'name': 'Tier 2@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-f85024c3-04fc-419f-84bf-073e21292c4c', 'distinguishedname': 'OU=TIER 2,DC=TESTLAB,DC=LOCALE', 'description': None, 'highvalue': False, 'blocksInheritance': False, 'owned': False}
# 4              {'domain': 'TESTLAB.LOCALE', 'name': 'T0 Admin@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-807c10fe-8e4f-4725-bc61-42c3885c545a', 'distinguishedname': 'OU=T0 ADMIN,DC=TESTLAB,DC=LOCALE', 'description': None, 'highvalue': False, 'blocksInheritance': False, 'owned': False}
#
#    type    l1      l2    l3  weight
# 0  node  Base  Domain  None       1
# 1  node  Base      OU  None       1
# 2  node  Base      OU  None       1
# 3  node  Base      OU  None       1
# 4  node  Base      OU  None       1

# %%
lastnode=(len(str(nodes['id'].iloc[-1])))

new_node_id = int('9' * lastnode)

print(f"The new node ID is: {new_node_id}")
# Out:
# The new node ID is: 9999

# %%
#prompt: create a new record in nodes where id=new_node_id, properties = {'domain': 'TESTLAB.LOCALE', 'name': 'ALL_T0@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-99999', 'distinguishedname': 'CN=ALL_T0,OU=ALL_T0,OU=ALL_T0,DC=TESTLAB,DC=LOCALE', 'description': 'All Tier 0 nodes', 'highvalue': True, 'admincount': True, 'owned': False}, type=node, l1=ALL_T0, l2=ALL_T0, l3=ALL_T0

# Create a dictionary with the new record's data
new_node_data = {
    'id': new_node_id,
    'properties': {'domain': 'TESTLAB.LOCALE', 'name': 'ALL_T0@TESTLAB.LOCALE', 'objectid': 'S-1-5-21-883232822-274137685-4173207997-' + str(new_node_id), 'distinguishedname': 'CN=ALL_T0,OU=ALL_T0,OU=ALL_T0,DC=TESTLAB,DC=LOCALE', 'description': 'All Tier 0 nodes', 'highvalue': True, 'admincount': True, 'owned': False},
    'type': 'node',
    'l1': 'ALL_T0',
    'l2': 'ALL_T0',
    'l3': 'ALL_T0',
    'weight': int(100) # Assuming a default weight, you can adjust if needed
}
#new_node_data

# Convert the dictionary to a DataFrame
new_node_df = pd.DataFrame([new_node_data])

# Concatenate the new DataFrame with the existing nodes DataFrame
nodes = pd.concat([nodes, new_node_df], ignore_index=True)

# Display the last few rows to confirm the addition
print("Nodes DataFrame after adding the new record:")
#display(nodes.tail())
# Out:
# Nodes DataFrame after adding the new record:

# %%
print(nodes[nodes['id'] == 26])
# print(nodes[nodes['id'] == 15])
# print(nodes[nodes['id'] == 26])
# print(nodes[nodes['id'] == 27])
# print(nodes[nodes['id'] == 637])
# print(nodes[nodes['id'] == 581])
# print(nodes[nodes['id'] == 633])
# print(nodes[nodes['id'] == 869])
# Out:
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight]
# Index: []

# %%
#1/0
# tier0_node_ids = nodes[nodes['properties'].apply(lambda x: 'Tier 0' in x.get('distinguishedname', ''))]['id'].tolist()
# tier0_node_ids
tier0_node_ids = []
tier0_node_ids = nodes[
    nodes['properties'].apply(
        lambda x: any(
            term in x.get('distinguishedname', '')
            for term in ['TIER 0', 'Tier 0', 'T0', 'TIER0']
        )
    )
]['id'].tolist()

filtered_nodes = nodes[
    nodes['properties'].apply(
        lambda x: re.search(r'.*-5[0-9]{2}$', x.get('objectid', '')) is not None and
                  x.get('highvalue', False) == True and
                  x.get('admincount', False) == True
    )
]

len(filtered_nodes)
# Iterate through the 'id' column of the filtered_nodes DataFrame
for node_id in filtered_nodes['id']:
    # Check if the node_id is not already in tier0_node_ids
    if node_id not in tier0_node_ids:
        # Append the node_id to the tier0_node_ids list
        tier0_node_ids.append(node_id)

# Print the updated length and contents of tier0_node_ids
print(f"tier 0 (after checking filtered_nodes): {len(tier0_node_ids)}")

print("Updated Tier 0 Node IDs:", tier0_node_ids)

for index, row in nodes.iterrows():
    properties = row['properties']
    node_id = row['id']

    # Check if 'properties' is a dictionary and contains 'distinguishedname'
    if isinstance(properties, dict) and 'distinguishedname' in properties:
        distinguishedname = properties['distinguishedname']

        # Check if "CN=Enterprise Admins," or "CN=Domain Admins," is in the distinguishedname
        if "CN=Enterprise Admins," in distinguishedname or "CN=Domain Admins," in distinguishedname or "CN=Administrator," in distinguishedname:
            # Append the id if it's not already in the list
            if node_id not in tier0_node_ids:
                tier0_node_ids.append(node_id)
# Out:
# tier 0 (after checking filtered_nodes): 71
# Updated Tier 0 Node IDs: [3145, 3148, 3149, 3150, 3151, 3298, 3300, 3302, 3306, 3309, 3310, 3313, 3314, 3316, 3319, 3324, 3325, 3326, 3328, 3329, 3331, 3341, 3353, 3366, 3372, 3378, 3380, 3404, 3454, 3524, 3542, 3572, 3604, 3606, 3624, 3658, 3701, 3720, 3721, 3744, 3746, 3750, 3758, 3778, 3782, 3807, 3832, 3856, 3867, 3868, 3926, 3960, 3970, 3972, 3996, 4020, 4025, 4037, 4045, 4052, 4091, 4097, 9999, 3181, 3183, 3185, 3204, 3205, 3210, 3211, 3217]

# %%
tier1_node_ids = nodes[
    nodes['properties'].apply(
        lambda x: any(
            term in x.get('distinguishedname', '')
            for term in ['TIER 1', 'Tier 1', 'T1']
        )
    ) & (~nodes['id'].isin(tier0_node_ids)) # Add this condition to exclude Tier 0 nodes
]['id'].tolist()

tier2_node_ids = nodes[
    nodes['properties'].apply(
        lambda x: any(
            term in x.get('distinguishedname', '')
            for term in ['TIER 2', 'Tier 2', 'T2']

        )
    ) & (~nodes['id'].isin(tier0_node_ids)) # Add this condition to exclude Tier 0 nodes
]['id'].tolist()

print(f"tier 0 ",len(tier0_node_ids))
# tier1_node_ids = nodes[nodes['properties'].apply(lambda x: 'Tier 1' in x.get('distinguishedname', ''))]['id'].tolist()
print(f"tier 1 ",len(tier1_node_ids))

# tier2_node_ids = nodes[nodes['properties'].apply(lambda x: 'Tier 2' in x.get('distinguishedname', ''))]['id'].tolist()
print(f"tier 2 ",len(tier2_node_ids))
# Out:
# tier 0  72
# tier 1  87
# tier 2  851

# %%
# Iterate through nodes and add a 'Tier0' column
nodes['Tier0'] = 0  # Initialize 'Tier0' column with 0
nodes['Tier1'] = 0  # Initialize 'Tier0' column with 0
nodes['Tier2'] = 0  # Initialize 'Tier0' column with 0

# Set 'Tier0' to 1 if node id is in tier0_node_ids
nodes.loc[nodes['id'].isin(tier0_node_ids), 'Tier0'] = 1

# Set 'Tier1' to 1 if node id is in tier1_node_ids
nodes.loc[nodes['id'].isin(tier1_node_ids), 'Tier1'] = 1

# Set 'Tier2' to 1 if node id is in tier2_node_ids
nodes.loc[nodes['id'].isin(tier2_node_ids), 'Tier2'] = 1

# Display the updated nodes DataFrame (optional)
# display(nodes.head())
# display(nodes.tail())

# %%
tier0_count = nodes[nodes['Tier0'] == 1].shape[0]
tier1_count = nodes[nodes['Tier1'] == 1].shape[0]
tier2_count = nodes[nodes['Tier2'] == 1].shape[0]

print(f"Number of nodes in Tier 0: {tier0_count}")
print(f"Number of nodes in Tier 1: {tier1_count}")
print(f"Number of nodes in Tier 2: {tier2_count}")
# Out:
# Number of nodes in Tier 0: 72
# Number of nodes in Tier 1: 87
# Number of nodes in Tier 2: 851

# %%
# import pandas as pd

# len(tier0_node_ids)
# tier0_node_ids = pd.DataFrame(tier0_node_ids)

# %%
for value in tier0_node_ids:
    if value  == new_node_id:
        nodes.loc[nodes['id'] == value, 'weight'] = 100
    else:
        nodes.loc[nodes['id'] == value, 'weight'] = 20

for value in tier1_node_ids:
    nodes.loc[nodes['id'] == value, 'weight'] = 10

for value in tier2_node_ids:
    nodes.loc[nodes['id'] == value, 'weight'] = 5

# %%
 nodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108 entries, 0 to 1107
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1108 non-null   int64
#  1   properties  1108 non-null   object
#  2   type        1108 non-null   object
#  3   l1          1108 non-null   object
#  4   l2          1108 non-null   object
#  5   l3          7 non-null      object
#  6   weight      1108 non-null   int64
#  7   Tier0       1108 non-null   int64
#  8   Tier1       1108 non-null   int64
#  9   Tier2       1108 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 86.7+ KB

# %%
# edges['source'] = edges['source'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
# edges['target'] = edges['target'].apply(lambda x: x.get('id') if isinstance(x, dict) else x)
# edges = edges.drop(columns=['properties']) #, 'id'])
# edges.head()
#edges = edges[:-51]
#edges = edges.drop(columns=['source', 'target', 'weight'])
# edges.head(60)
# edges.tail(58)
# edges[edges['weight'] >= 8]

# %%
edges = edges[:-265]
edges.tail()
# Out:
#         id source source_node target target_node          type  \
# 6811  6811   3472        User   3945    Computer  relationship
# 6812  6812   3655        User   4006    Computer  relationship
# 6813  6813   3724        User   3863    Computer  relationship
# 6814  6814   3751        User   4006    Computer  relationship
# 6815  6815   3572        User   4028    Computer  relationship
#
#                   label
# 6811        CanPSRemote
# 6812             CanRDP
# 6813            AdminTo
# 6814        CanPSRemote
# 6815  AllowedToDelegate

# %%
# prompt: for each value in tier0_node_ids add a new record in edges where start = value and end = new_node_id, label=TIER0,weight=100 id=id+1

# Get the maximum existing edge ID
max_edge_id = edges['id'].max()
max_edge_id
i=1
new_edges = []
for i, tier0_id in enumerate(tier0_node_ids):
    new_edge = {
        'type': 'relationship',  # Assuming type is always 'relationship' for edges
        'source': tier0_id,
        'source_node': 'TIER0',
        'target_node': 'TIER0',
        'target': new_node_id,
        'label': 'TIER0',
        'weight': 100,
        'id': max_edge_id + i + 1 # Assign a unique ID
    }
    new_edges.append(new_edge)

# Convert the list of new edges to a DataFrame
new_edges_df = pd.DataFrame(new_edges)

# Concatenate the new edges DataFrame with the existing edges DataFrame
edges = pd.concat([edges, new_edges_df], ignore_index=True)

# Display the last few rows to confirm the addition
print("Edges DataFrame after adding new TIER0 edges:")
display(edges.tail(266))
# Out:
# Edges DataFrame after adding new TIER0 edges:
#         id source source_node target target_node          type  \
# 6622  6622   4012    Computer   3329        User  relationship
# 6623  6623   4012    Computer   3324        User  relationship
# 6624  6624   3847    Computer   4098        User  relationship
# 6625  6625   3821    Computer   3312        User  relationship
# 6626  6626   3823    Computer   3298        User  relationship
# 6627  6627   3857    Computer   3338        User  relationship
# 6628  6628   4029    Computer   3343        User  relationship
# 6629  6629   4071    Computer   3298        User  relationship
# 6630  6630   3898    Computer   3314        User  relationship
# 6631  6631   3968    Computer   3309        User  relationship
# 6632  6632   3845    Computer   3327        User  relationship
# 6633  6633   3905    Computer   3336        User  relationship
# 6634  6634   4058    Computer   3302        User  relationship
# 6635  6635   3858    Computer   3325        User  relationship
# 6636  6636   4065    Computer   3309        User  relationship
# 6637  6637   4028    Computer   3314        User  relationship
# 6638  6638   3944    Computer   3329        User  relationship
# 6639  6639   3909    Computer   3305        User  relationship
# 6640  6640   3873    Computer   3310        User  relationship
# 6641  6641   4084    Computer   3310        User  relationship
# 6642  6642   3872    Computer   3331        User  relationship
# 6643  6643   4080    Computer   3301        User  relationship
# 6644  6644   3835    Computer   3311        User  relationship
# 6645  6645   4016    Computer   3331        User  relationship
# 6646  6646   3827    Computer   3310        User  relationship
# 6647  6647   3816    Computer   3326        User  relationship
# 6648  6648   4056    Computer   3298        User  relationship
# 6649  6649   4024    Computer   3326        User  relationship
# 6650  6650   3857    Computer   3303        User  relationship
# 6651  6651   3795    Computer   3308        User  relationship
# 6652  6652   4027    Computer   3314        User  relationship
# 6653  6653   4046    Computer   3310        User  relationship
# 6654  6654   3930    Computer   4098        User  relationship
# 6655  6655   4036    Computer   3305        User  relationship
# 6656  6656   3795    Computer   3303        User  relationship
# 6657  6657   4087    Computer   3300        User  relationship
# 6658  6658   3985    Computer   3332        User  relationship
# 6659  6659   3916    Computer   3328        User  relationship
# 6660  6660   4060    Computer   3343        User  relationship
# 6661  6661   3906    Computer   3331        User  relationship
# 6662  6662   3935    Computer   3336        User  relationship
# 6663  6663   4017    Computer   3331        User  relationship
# 6664  6664   4042    Computer   3343        User  relationship
# 6665  6665   3839    Computer   3303        User  relationship
# 6666  6666   4079    Computer   3341        User  relationship
# 6667  6667   4039    Computer   3327        User  relationship
# 6668  6668   3962    Computer   3327        User  relationship
# 6669  6669   3851    Computer   3295        User  relationship
# 6670  6670   4086    Computer   3314        User  relationship
# 6671  6671   4030    Computer   3325        User  relationship
# 6672  6672   4018    Computer   3328        User  relationship
# 6673  6673   3863    Computer   3309        User  relationship
# 6674  6674   3991    Computer   3306        User  relationship
# 6675  6675   3298        User   3249    Computer  relationship
# 6676  6676   3306        User   3249    Computer  relationship
# 6677  6677   3314        User   3248    Computer  relationship
# 6678  6678   3314        User   3249    Computer  relationship
# 6679  6679   3341        User   3248    Computer  relationship
# 6680  6680   3341        User   3249    Computer  relationship
# 6681  6681   4097        User   3249    Computer  relationship
# 6682  6682   3309        User   3249    Computer  relationship
# 6683  6683   3328        User   3248    Computer  relationship
# 6684  6684   3328        User   3249    Computer  relationship
# 6685  6685   3183       Group   3173          OU  relationship
# 6686  6686   3205       Group   3170          OU  relationship
# 6687  6687   3204       Group   3177          OU  relationship
# 6688  6688   3235       Group   3180          OU  relationship
# 6689  6689   3236       Group   3161          OU  relationship
# 6690  6690   3237       Group   3176          OU  relationship
# 6691  6691   3238       Group   3171          OU  relationship
# 6692  6692   3239       Group   3176          OU  relationship
# 6693  6693   3240       Group   3173          OU  relationship
# 6694  6694   3241       Group   3173          OU  relationship
# 6695  6695   3242       Group   3180          OU  relationship
# 6696  6696   3556        User   4020    Computer  relationship
# 6697  6697   3356        User   3929    Computer  relationship
# 6698  6698   3638        User   4006    Computer  relationship
# 6699  6699   3592        User   3986    Computer  relationship
# 6700  6700   3573        User   3991    Computer  relationship
# 6701  6701   3363        User   4037    Computer  relationship
# 6702  6702   3711        User   4061    Computer  relationship
# 6703  6703   3502        User   3970    Computer  relationship
# 6704  6704   3348        User   3867    Computer  relationship
# 6705  6705   3658        User   3972    Computer  relationship
# 6706  6706   3679        User   3853    Computer  relationship
# 6707  6707   3425        User   3841    Computer  relationship
# 6708  6708   3637        User   3991    Computer  relationship
# 6709  6709   3462        User   4044    Computer  relationship
# 6710  6710   3408        User   3960    Computer  relationship
# 6711  6711   3599        User   4095    Computer  relationship
# 6712  6712   3528        User   3926    Computer  relationship
# 6713  6713   3623        User   3832    Computer  relationship
# 6714  6714   3356        User   4025    Computer  relationship
# 6715  6715   3699        User   3856    Computer  relationship
# 6716  6716   3358        User   3827    Computer  relationship
# 6717  6717   3446        User   4096    Computer  relationship
# 6718  6718   3785        User   4012    Computer  relationship
# 6719  6719   3402        User   3906    Computer  relationship
# 6720  6720   3650        User   3987    Computer  relationship
# 6721  6721   3523        User   4028    Computer  relationship
# 6722  6722   3369        User   4044    Computer  relationship
# 6723  6723   3488        User   3866    Computer  relationship
# 6724  6724   3528        User   3986    Computer  relationship
# 6725  6725   3727        User   3994    Computer  relationship
# 6726  6726   3646        User   3942    Computer  relationship
# 6727  6727   3477        User   4096    Computer  relationship
# 6728  6728   3395        User   4092    Computer  relationship
# 6729  6729   3399        User   3951    Computer  relationship
# 6730  6730   3612        User   3896    Computer  relationship
# 6731  6731   3717        User   3849    Computer  relationship
# 6732  6732   3391        User   4008    Computer  relationship
# 6733  6733   3582        User   3944    Computer  relationship
# 6734  6734   3648        User   4012    Computer  relationship
# 6735  6735   3433        User   4096    Computer  relationship
# 6736  6736   3729        User   3889    Computer  relationship
# 6737  6737   3728        User   3873    Computer  relationship
# 6738  6738   3704        User   3942    Computer  relationship
# 6739  6739   3660        User   3951    Computer  relationship
# 6740  6740   3349        User   4028    Computer  relationship
# 6741  6741   3553        User   4058    Computer  relationship
# 6742  6742   3394        User   3829    Computer  relationship
# 6743  6743   3348        User   4012    Computer  relationship
# 6744  6744   3548        User   3945    Computer  relationship
# 6745  6745   3528        User   4095    Computer  relationship
# 6746  6746   3468        User   3841    Computer  relationship
# 6747  6747   3401        User   3812    Computer  relationship
# 6748  6748   3462        User   3986    Computer  relationship
# 6749  6749   3668        User   3889    Computer  relationship
# 6750  6750   3756        User   3898    Computer  relationship
# 6751  6751   3436        User   3883    Computer  relationship
# 6752  6752   3707        User   3829    Computer  relationship
# 6753  6753   3734        User   3951    Computer  relationship
# 6754  6754   3654        User   4059    Computer  relationship
# 6755  6755   3396        User   3849    Computer  relationship
# 6756  6756   3736        User   3951    Computer  relationship
# 6757  6757   3634        User   3812    Computer  relationship
# 6758  6758   3726        User   3997    Computer  relationship
# 6759  6759   3369        User   3948    Computer  relationship
# 6760  6760   3646        User   4028    Computer  relationship
# 6761  6761   3499        User   3942    Computer  relationship
# 6762  6762   3558        User   4092    Computer  relationship
# 6763  6763   3403        User   3964    Computer  relationship
# 6764  6764   3767        User   4028    Computer  relationship
# 6765  6765   3625        User   3948    Computer  relationship
# 6766  6766   3587        User   3948    Computer  relationship
# 6767  6767   3681        User   3906    Computer  relationship
# 6768  6768   3513        User   3827    Computer  relationship
# 6769  6769   3735        User   3812    Computer  relationship
# 6770  6770   3344        User   3848    Computer  relationship
# 6771  6771   3374        User   3898    Computer  relationship
# 6772  6772   3443        User   3896    Computer  relationship
# 6773  6773   3707        User   3830    Computer  relationship
# 6774  6774   3781        User   3852    Computer  relationship
# 6775  6775   3753        User   3937    Computer  relationship
# 6776  6776   3701        User   3885    Computer  relationship
# 6777  6777   3503        User   3982    Computer  relationship
# 6778  6778   3453        User   4012    Computer  relationship
# 6779  6779   3658        User   3852    Computer  relationship
# 6780  6780   3540        User   3937    Computer  relationship
# 6781  6781   3484        User   3812    Computer  relationship
# 6782  6782   3551        User   3945    Computer  relationship
# 6783  6783   3585        User   3964    Computer  relationship
# 6784  6784   3482        User   3929    Computer  relationship
# 6785  6785   3592        User   3866    Computer  relationship
# 6786  6786   3411        User   4072    Computer  relationship
# 6787  6787   3606        User   3937    Computer  relationship
# 6788  6788   3681        User   4028    Computer  relationship
# 6789  6789   3622        User   3896    Computer  relationship
# 6790  6790   3656        User   3964    Computer  relationship
# 6791  6791   3616        User   3982    Computer  relationship
# 6792  6792   3670        User   3896    Computer  relationship
# 6793  6793   3620        User   3852    Computer  relationship
# 6794  6794   3363        User   3944    Computer  relationship
# 6795  6795   3485        User   3889    Computer  relationship
# 6796  6796   3720        User   4066    Computer  relationship
# 6797  6797   3539        User   3997    Computer  relationship
# 6798  6798   3532        User   3945    Computer  relationship
# 6799  6799   3549        User   4006    Computer  relationship
# 6800  6800   3466        User   3994    Computer  relationship
# 6801  6801   3391        User   3883    Computer  relationship
# 6802  6802   3437        User   3827    Computer  relationship
# 6803  6803   3349        User   3841    Computer  relationship
# 6804  6804   3440        User   3997    Computer  relationship
# 6805  6805   3705        User   4059    Computer  relationship
# 6806  6806   3656        User   4006    Computer  relationship
# 6807  6807   3367        User   3841    Computer  relationship
# 6808  6808   3606        User   4061    Computer  relationship
# 6809  6809   3451        User   3910    Computer  relationship
# 6810  6810   3587        User   3829    Computer  relationship
# 6811  6811   3472        User   3945    Computer  relationship
# 6812  6812   3655        User   4006    Computer  relationship
# 6813  6813   3724        User   3863    Computer  relationship
# 6814  6814   3751        User   4006    Computer  relationship
# 6815  6815   3572        User   4028    Computer  relationship
# 6816  6816   3145       TIER0   9999       TIER0  relationship
# 6817  6817   3148       TIER0   9999       TIER0  relationship
# 6818  6818   3149       TIER0   9999       TIER0  relationship
# 6819  6819   3150       TIER0   9999       TIER0  relationship
# 6820  6820   3151       TIER0   9999       TIER0  relationship
# 6821  6821   3298       TIER0   9999       TIER0  relationship
# 6822  6822   3300       TIER0   9999       TIER0  relationship
# 6823  6823   3302       TIER0   9999       TIER0  relationship
# 6824  6824   3306       TIER0   9999       TIER0  relationship
# 6825  6825   3309       TIER0   9999       TIER0  relationship
# 6826  6826   3310       TIER0   9999       TIER0  relationship
# 6827  6827   3313       TIER0   9999       TIER0  relationship
# 6828  6828   3314       TIER0   9999       TIER0  relationship
# 6829  6829   3316       TIER0   9999       TIER0  relationship
# 6830  6830   3319       TIER0   9999       TIER0  relationship
# 6831  6831   3324       TIER0   9999       TIER0  relationship
# 6832  6832   3325       TIER0   9999       TIER0  relationship
# 6833  6833   3326       TIER0   9999       TIER0  relationship
# 6834  6834   3328       TIER0   9999       TIER0  relationship
# 6835  6835   3329       TIER0   9999       TIER0  relationship
# 6836  6836   3331       TIER0   9999       TIER0  relationship
# 6837  6837   3341       TIER0   9999       TIER0  relationship
# 6838  6838   3353       TIER0   9999       TIER0  relationship
# 6839  6839   3366       TIER0   9999       TIER0  relationship
# 6840  6840   3372       TIER0   9999       TIER0  relationship
# 6841  6841   3378       TIER0   9999       TIER0  relationship
# 6842  6842   3380       TIER0   9999       TIER0  relationship
# 6843  6843   3404       TIER0   9999       TIER0  relationship
# 6844  6844   3454       TIER0   9999       TIER0  relationship
# 6845  6845   3524       TIER0   9999       TIER0  relationship
# 6846  6846   3542       TIER0   9999       TIER0  relationship
# 6847  6847   3572       TIER0   9999       TIER0  relationship
# 6848  6848   3604       TIER0   9999       TIER0  relationship
# 6849  6849   3606       TIER0   9999       TIER0  relationship
# 6850  6850   3624       TIER0   9999       TIER0  relationship
# 6851  6851   3658       TIER0   9999       TIER0  relationship
# 6852  6852   3701       TIER0   9999       TIER0  relationship
# 6853  6853   3720       TIER0   9999       TIER0  relationship
# 6854  6854   3721       TIER0   9999       TIER0  relationship
# 6855  6855   3744       TIER0   9999       TIER0  relationship
# 6856  6856   3746       TIER0   9999       TIER0  relationship
# 6857  6857   3750       TIER0   9999       TIER0  relationship
# 6858  6858   3758       TIER0   9999       TIER0  relationship
# 6859  6859   3778       TIER0   9999       TIER0  relationship
# 6860  6860   3782       TIER0   9999       TIER0  relationship
# 6861  6861   3807       TIER0   9999       TIER0  relationship
# 6862  6862   3832       TIER0   9999       TIER0  relationship
# 6863  6863   3856       TIER0   9999       TIER0  relationship
# 6864  6864   3867       TIER0   9999       TIER0  relationship
# 6865  6865   3868       TIER0   9999       TIER0  relationship
# 6866  6866   3926       TIER0   9999       TIER0  relationship
# 6867  6867   3960       TIER0   9999       TIER0  relationship
# 6868  6868   3970       TIER0   9999       TIER0  relationship
# 6869  6869   3972       TIER0   9999       TIER0  relationship
# 6870  6870   3996       TIER0   9999       TIER0  relationship
# 6871  6871   4020       TIER0   9999       TIER0  relationship
# 6872  6872   4025       TIER0   9999       TIER0  relationship
# 6873  6873   4037       TIER0   9999       TIER0  relationship
# 6874  6874   4045       TIER0   9999       TIER0  relationship
# 6875  6875   4052       TIER0   9999       TIER0  relationship
# 6876  6876   4091       TIER0   9999       TIER0  relationship
# 6877  6877   4097       TIER0   9999       TIER0  relationship
# 6878  6878   9999       TIER0   9999       TIER0  relationship
# 6879  6879   3181       TIER0   9999       TIER0  relationship
# 6880  6880   3183       TIER0   9999       TIER0  relationship
# 6881  6881   3185       TIER0   9999       TIER0  relationship
# 6882  6882   3204       TIER0   9999       TIER0  relationship
# 6883  6883   3205       TIER0   9999       TIER0  relationship
# 6884  6884   3210       TIER0   9999       TIER0  relationship
# 6885  6885   3211       TIER0   9999       TIER0  relationship
# 6886  6886   3217       TIER0   9999       TIER0  relationship
# 6887  6887   3291       TIER0   9999       TIER0  relationship
#
#                   label  weight
# 6622         HasSession     NaN
# 6623         HasSession     NaN
# 6624         HasSession     NaN
# 6625         HasSession     NaN
# 6626         HasSession     NaN
# 6627         HasSession     NaN
# 6628         HasSession     NaN
# 6629         HasSession     NaN
# 6630         HasSession     NaN
# 6631         HasSession     NaN
# 6632         HasSession     NaN
# 6633         HasSession     NaN
# 6634         HasSession     NaN
# 6635         HasSession     NaN
# 6636         HasSession     NaN
# 6637         HasSession     NaN
# 6638         HasSession     NaN
# 6639         HasSession     NaN
# 6640         HasSession     NaN
# 6641         HasSession     NaN
# 6642         HasSession     NaN
# 6643         HasSession     NaN
# 6644         HasSession     NaN
# 6645         HasSession     NaN
# 6646         HasSession     NaN
# 6647         HasSession     NaN
# 6648         HasSession     NaN
# 6649         HasSession     NaN
# 6650         HasSession     NaN
# 6651         HasSession     NaN
# 6652         HasSession     NaN
# 6653         HasSession     NaN
# 6654         HasSession     NaN
# 6655         HasSession     NaN
# 6656         HasSession     NaN
# 6657         HasSession     NaN
# 6658         HasSession     NaN
# 6659         HasSession     NaN
# 6660         HasSession     NaN
# 6661         HasSession     NaN
# 6662         HasSession     NaN
# 6663         HasSession     NaN
# 6664         HasSession     NaN
# 6665         HasSession     NaN
# 6666         HasSession     NaN
# 6667         HasSession     NaN
# 6668         HasSession     NaN
# 6669         HasSession     NaN
# 6670         HasSession     NaN
# 6671         HasSession     NaN
# 6672         HasSession     NaN
# 6673         HasSession     NaN
# 6674         HasSession     NaN
# 6675         HasSession     NaN
# 6676         HasSession     NaN
# 6677         HasSession     NaN
# 6678         HasSession     NaN
# 6679         HasSession     NaN
# 6680         HasSession     NaN
# 6681         HasSession     NaN
# 6682         HasSession     NaN
# 6683         HasSession     NaN
# 6684         HasSession     NaN
# 6685             CanRDP     NaN
# 6686             CanRDP     NaN
# 6687             CanRDP     NaN
# 6688   ReadLAPSPassword     NaN
# 6689  AllowedToDelegate     NaN
# 6690   ReadLAPSPassword     NaN
# 6691        ExecuteDCOM     NaN
# 6692        ExecuteDCOM     NaN
# 6693        ExecuteDCOM     NaN
# 6694             CanRDP     NaN
# 6695   ReadLAPSPassword     NaN
# 6696             CanRDP     NaN
# 6697  AllowedToDelegate     NaN
# 6698  AllowedToDelegate     NaN
# 6699       AllowedToAct     NaN
# 6700  AllowedToDelegate     NaN
# 6701  AllowedToDelegate     NaN
# 6702   ReadLAPSPassword     NaN
# 6703        CanPSRemote     NaN
# 6704        CanPSRemote     NaN
# 6705  AllowedToDelegate     NaN
# 6706             CanRDP     NaN
# 6707             CanRDP     NaN
# 6708            AdminTo     NaN
# 6709        CanPSRemote     NaN
# 6710        CanPSRemote     NaN
# 6711   ReadLAPSPassword     NaN
# 6712        ExecuteDCOM     NaN
# 6713       AllowedToAct     NaN
# 6714  AllowedToDelegate     NaN
# 6715        ExecuteDCOM     NaN
# 6716       AllowedToAct     NaN
# 6717        CanPSRemote     NaN
# 6718        CanPSRemote     NaN
# 6719            AdminTo     NaN
# 6720           SQLAdmin     NaN
# 6721   ReadLAPSPassword     NaN
# 6722        CanPSRemote     NaN
# 6723             CanRDP     NaN
# 6724       AllowedToAct     NaN
# 6725  AllowedToDelegate     NaN
# 6726        ExecuteDCOM     NaN
# 6727   ReadLAPSPassword     NaN
# 6728  AllowedToDelegate     NaN
# 6729           SQLAdmin     NaN
# 6730        CanPSRemote     NaN
# 6731   ReadLAPSPassword     NaN
# 6732   ReadLAPSPassword     NaN
# 6733            AdminTo     NaN
# 6734  AllowedToDelegate     NaN
# 6735            AdminTo     NaN
# 6736        ExecuteDCOM     NaN
# 6737           SQLAdmin     NaN
# 6738           SQLAdmin     NaN
# 6739   ReadLAPSPassword     NaN
# 6740           SQLAdmin     NaN
# 6741            AdminTo     NaN
# 6742       AllowedToAct     NaN
# 6743             CanRDP     NaN
# 6744  AllowedToDelegate     NaN
# 6745  AllowedToDelegate     NaN
# 6746       AllowedToAct     NaN
# 6747        ExecuteDCOM     NaN
# 6748   ReadLAPSPassword     NaN
# 6749       AllowedToAct     NaN
# 6750   ReadLAPSPassword     NaN
# 6751            AdminTo     NaN
# 6752       AllowedToAct     NaN
# 6753            AdminTo     NaN
# 6754       AllowedToAct     NaN
# 6755           SQLAdmin     NaN
# 6756           SQLAdmin     NaN
# 6757             CanRDP     NaN
# 6758             CanRDP     NaN
# 6759        ExecuteDCOM     NaN
# 6760  AllowedToDelegate     NaN
# 6761  AllowedToDelegate     NaN
# 6762   ReadLAPSPassword     NaN
# 6763        ExecuteDCOM     NaN
# 6764  AllowedToDelegate     NaN
# 6765   ReadLAPSPassword     NaN
# 6766   ReadLAPSPassword     NaN
# 6767  AllowedToDelegate     NaN
# 6768       AllowedToAct     NaN
# 6769   ReadLAPSPassword     NaN
# 6770        ExecuteDCOM     NaN
# 6771             CanRDP     NaN
# 6772  AllowedToDelegate     NaN
# 6773        CanPSRemote     NaN
# 6774        CanPSRemote     NaN
# 6775            AdminTo     NaN
# 6776  AllowedToDelegate     NaN
# 6777             CanRDP     NaN
# 6778  AllowedToDelegate     NaN
# 6779             CanRDP     NaN
# 6780        ExecuteDCOM     NaN
# 6781   ReadLAPSPassword     NaN
# 6782           SQLAdmin     NaN
# 6783  AllowedToDelegate     NaN
# 6784        ExecuteDCOM     NaN
# 6785        ExecuteDCOM     NaN
# 6786            AdminTo     NaN
# 6787        CanPSRemote     NaN
# 6788  AllowedToDelegate     NaN
# 6789        ExecuteDCOM     NaN
# 6790   ReadLAPSPassword     NaN
# 6791             CanRDP     NaN
# 6792       AllowedToAct     NaN
# 6793        ExecuteDCOM     NaN
# 6794       AllowedToAct     NaN
# 6795  AllowedToDelegate     NaN
# 6796            AdminTo     NaN
# 6797        ExecuteDCOM     NaN
# 6798            AdminTo     NaN
# 6799       AllowedToAct     NaN
# 6800           SQLAdmin     NaN
# 6801             CanRDP     NaN
# 6802   ReadLAPSPassword     NaN
# 6803        ExecuteDCOM     NaN
# 6804            AdminTo     NaN
# 6805   ReadLAPSPassword     NaN
# 6806        CanPSRemote     NaN
# 6807  AllowedToDelegate     NaN
# 6808        ExecuteDCOM     NaN
# 6809        CanPSRemote     NaN
# 6810        ExecuteDCOM     NaN
# 6811        CanPSRemote     NaN
# 6812             CanRDP     NaN
# 6813            AdminTo     NaN
# 6814        CanPSRemote     NaN
# 6815  AllowedToDelegate     NaN
# 6816              TIER0   100.0
# 6817              TIER0   100.0
# 6818              TIER0   100.0
# 6819              TIER0   100.0
# 6820              TIER0   100.0
# 6821              TIER0   100.0
# 6822              TIER0   100.0
# 6823              TIER0   100.0
# 6824              TIER0   100.0
# 6825              TIER0   100.0
# 6826              TIER0   100.0
# 6827              TIER0   100.0
# 6828              TIER0   100.0
# 6829              TIER0   100.0
# 6830              TIER0   100.0
# 6831              TIER0   100.0
# 6832              TIER0   100.0
# 6833              TIER0   100.0
# 6834              TIER0   100.0
# 6835              TIER0   100.0
# 6836              TIER0   100.0
# 6837              TIER0   100.0
# 6838              TIER0   100.0
# 6839              TIER0   100.0
# 6840              TIER0   100.0
# 6841              TIER0   100.0
# 6842              TIER0   100.0
# 6843              TIER0   100.0
# 6844              TIER0   100.0
# 6845              TIER0   100.0
# 6846              TIER0   100.0
# 6847              TIER0   100.0
# 6848              TIER0   100.0
# 6849              TIER0   100.0
# 6850              TIER0   100.0
# 6851              TIER0   100.0
# 6852              TIER0   100.0
# 6853              TIER0   100.0
# 6854              TIER0   100.0
# 6855              TIER0   100.0
# 6856              TIER0   100.0
# 6857              TIER0   100.0
# 6858              TIER0   100.0
# 6859              TIER0   100.0
# 6860              TIER0   100.0
# 6861              TIER0   100.0
# 6862              TIER0   100.0
# 6863              TIER0   100.0
# 6864              TIER0   100.0
# 6865              TIER0   100.0
# 6866              TIER0   100.0
# 6867              TIER0   100.0
# 6868              TIER0   100.0
# 6869              TIER0   100.0
# 6870              TIER0   100.0
# 6871              TIER0   100.0
# 6872              TIER0   100.0
# 6873              TIER0   100.0
# 6874              TIER0   100.0
# 6875              TIER0   100.0
# 6876              TIER0   100.0
# 6877              TIER0   100.0
# 6878              TIER0   100.0
# 6879              TIER0   100.0
# 6880              TIER0   100.0
# 6881              TIER0   100.0
# 6882              TIER0   100.0
# 6883              TIER0   100.0
# 6884              TIER0   100.0
# 6885              TIER0   100.0
# 6886              TIER0   100.0
# 6887              TIER0   100.0

# %%
# Apply the weights based on the 'label' column

def assign_weight(label):
    if label == "GenericAll":
        return 9
    elif label == "Owns":
        return 10
    elif label == "GenericWrite":
        return 2
    elif label == "AllExtendedRights":
        return 6
    elif label == "CanRDP":
        return 2
    elif label == "Contains":
        return 2
    elif label == "DCSync":
        return 8
    elif label == "WriteDacl":
        return 5
    elif label == "WriteOwner":
        return 7
    elif label == "AddKeyCredentialLink":
        return 6
    elif label == "AdminTo":
        return 8
    elif label == "MemberOf":
        return 2
    elif label == "CanPSRemote":
        return 2
    elif label == "ExecuteDCOM":
        return 2
    elif label == "GPLink":
        return 3
    elif label == "HasSession":
        return 9
    elif label == "ReadLAPSPassword":
        return 2
    elif label == "GetChanges":
        return 3
    elif label == "GetChangesAll":
        return 3
    elif label == "AddSelf":
        return 3
    elif label == "ForceChangePassword":
        return 3
    elif label == "AddMember":
        return 5
    elif label == "AllowedToDelegate":
        return 5
    elif label == "AllowedToAct":
        return 4
    elif label == "TIER0":
        return 100
    else:
        return 1 # Default weight for other labels

edges['weight'] = edges['label'].apply(assign_weight)

# Display the updated edges_all DataFrame with the 'weight' column
print("\nEdges_all DataFrame with weight column:")
#edges.head()
#clear_output()
#edges.tail()
# Out:
# Edges_all DataFrame with weight column:

# %%
# prompt: create a unique id for each row, make sure it is of type int64
#edges = edges.drop(columns=['id'])
import numpy as np
#edges['id'] = np.arange(len(edges)).astype('int64')
#edges.head()
edges['id'] = edges['id'].astype('int64')
edges['source'] = edges['source'].astype('int64')
edges['target'] = edges['target'].astype('int64')
edges['weight'] = edges['weight'].astype('int64')
edges.info()
display(edges.head())
display(edges.tail())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6888 entries, 0 to 6887
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6888 non-null   int64
#  1   source       6888 non-null   int64
#  2   source_node  6888 non-null   object
#  3   target       6888 non-null   int64
#  4   target_node  6888 non-null   object
#  5   type         6888 non-null   object
#  6   label        6888 non-null   object
#  7   weight       6888 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 430.6+ KB
#    id  source source_node  target target_node          type     label  weight
# 0   0    3141      Domain    3142          OU  relationship  Contains       2
# 1   1    3141      Domain    3143          OU  relationship  Contains       2
# 2   2    3141      Domain    3144          OU  relationship  Contains       2
# 3   3    3142          OU    3145          OU  relationship  Contains       2
# 4   4    3142          OU    3146          OU  relationship  Contains       2
#         id  source source_node  target target_node          type  label  \
# 6883  6883    3205       TIER0    9999       TIER0  relationship  TIER0
# 6884  6884    3210       TIER0    9999       TIER0  relationship  TIER0
# 6885  6885    3211       TIER0    9999       TIER0  relationship  TIER0
# 6886  6886    3217       TIER0    9999       TIER0  relationship  TIER0
# 6887  6887    3291       TIER0    9999       TIER0  relationship  TIER0
#
#       weight
# 6883     100
# 6884     100
# 6885     100
# 6886     100
# 6887     100

# %%
# selected_edges = edges[(edges['source'].isin(tier2_node_ids))  & (edges['target'].isin(tier0_node_ids)) & (~edges['source'].isin(tier0_node_ids)) & (~edges['target'].isin(tier2_node_ids))]
# scratch = selected_edges[selected_edges['weight'] == 8]
# scratch(0)

# df_max_weight =0
# df_max_weight = df_shortest_paths_with_weight['total_weight'].max()
# df_max = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == df_max_weight]

# %%
selected_edges_t0 = edges[(edges['source'].isin(tier2_node_ids))  & (edges['target'].isin(tier0_node_ids)) & (~edges['source'].isin(tier0_node_ids)) & (~edges['target'].isin(tier2_node_ids))]
#scratch = selected_edges[selected_edges['weight'] == 8]
print(len(selected_edges_t0))
selected_nodes = nodes[nodes['id'].isin(tier2_node_ids)]
print(len(selected_nodes))
# Out:
# 70
# 851

# %% [markdown]
# # Dijkstra

# %%
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Add nodes with their weights
for index, row in selected_nodes.iterrows():
    # Ensure node IDs are integers when adding to the graph
    G.add_node(int(row['id']), weight=row['weight'])

# Add edges with their weights
for index, row in selected_edges_t0.iterrows():
#for index, row in scratch.iterrows():
    # Ensure edge endpoints are integers when adding to the graph
    G.add_edge(row['source'], row['target'], weight=row['weight'])

# Compute shortest paths from each source node to all reachable nodes
shortest_paths = {}
for source in G.nodes():
    # Use single_source_dijkstra_path to find paths from one source to all others
    shortest_paths[source] = nx.single_source_dijkstra_path(G, source)

# Filter out paths from a node to itself and store in a new dictionary
shortest_paths_filtered = {
    source: {
        target: path
        for target, path in paths.items()
        if source != target
        #if target in tier0_node_ids
        #if source in tier2_node_ids
    }
    for source, paths in shortest_paths.items()
}
len(shortest_paths_filtered)

# Print the shortest paths (optional)
# for source, paths in shortest_paths_filtered.items():
#   if paths:
#     #print(f"Shortest paths from node {source}:")
#     for target, path in paths.items():
#         #print(f"  To node {target}: {path}")
#         ShortestPath = source, target, path
#        # print(ShortestPath)
# Out:
# 898

# %%
tier2_node_ids = pd.DataFrame(tier2_node_ids)
#

# %%
def get_edge_weight(start_node, end_node):
    # Find the corresponding edge in the 'edges' DataFrame
    edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]
    if not edge.empty:
        # Assuming there is only one edge with this start and end for simplicity in path finding
        # If multiple edges exist, you might need to adjust based on which edge is part of the shortest path calculation
        return edge.iloc[0]['weight']

#     if not edge.empty:
# # Return the weight from the resulting DataFrame
#         return edge['weight'].values[0]
#     else:
#         return None

shortest_paths_list = []
for source, paths in shortest_paths_filtered.items():
    if paths:
        for target, path in paths.items():
#            get_edge_weight(source, target)
            shortest_paths_list.append({
                'source': int(source),
                'target': int(target),
                'path': path,
                'weight': get_edge_weight(source, target)
            })

# Convert the list of dictionaries to a DataFrame
#shortest_paths_list = pd.DataFrame(shortest_paths_list)

# #shortest_paths_list.info()
# #short = shortest_paths_list[shortest_paths_list['target'].isin(tier2_node_ids)]
# #short1 = short[~short['source'].isin(tier0_node_ids)]
# #len(short)

# %%
shortest_paths_list = pd.DataFrame(shortest_paths_list)
shortest_paths_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   source  5 non-null      int64
#  1   target  5 non-null      int64
#  2   path    5 non-null      object
#  3   weight  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 292.0+ bytes

# %%
#tier0_node_ids.info()

# %%
display(edges[edges['source'] == 286])
# Out:
# Empty DataFrame
# Columns: [id, source, source_node, target, target_node, type, label, weight]
# Index: []

# %%
import pandas as pd
shortest_paths_list = pd.DataFrame(shortest_paths_list)
#short= shortest_paths_list[shortest_paths_list['source'] isin tier2_node_ids]

#tier2_node_ids = pd.DataFrame(tier2_node_ids)

def get_edge_weight(start_node, end_node):
    # Find the corresponding edge in the 'edges' DataFrame
    edge = edges[(edges['source'] == start_node) & (edges['target'] == end_node)]
    # if not edge.empty:
    #     # Assuming there is only one edge with this start and end for simplicity in path finding
    #     # If multiple edges exist, you might need to adjust based on which edge is part of the shortest path calculation
    return edge.iloc[0]['weight']

#     if not edge.empty:
# # Return the weight from the resulting DataFrame
#         return edge['weight'].values[0]
#     else:
#         return None

# short = shortest_paths_list[shortest_paths_list['source'].isin(tier2_node_ids)]
# short1 = short[short['target'].isin(tier0_node_ids)]
# len(short1)
# max_value = short1['total_weight'].max()
# max_rows = short1[short1['total_weight'] == max_value]
# len(max_rows)
#df_filtered_paths.loc[df_filtered_paths['total_weight'].idxmin()]

# Calculate the total weight for each shortest path

shortest_paths_with_weight = []

# Iterate through the DataFrame 'short1' using 'iterrows()'
for index, path_info in shortest_paths_list.iterrows():
    total_weight = 0
# The path is expected to be a list of node IDs
    path = path_info['path']
    source = path_info['source']
    target = path_info['target']

# Ensure that 'path' is a list; you may need to adjust this if 'path' is a string
    if isinstance(path, list):
    # Iterate through the path to get the edges
        for i in range(len(path) - 1):
            start_node = path[i]
            end_node = path[i + 1]
        # Assuming you have a way to get the weight of the edge between start_node and end_node
        # For example, if you have a function or a mapping for edge weights
            edge_weight = get_edge_weight(start_node, end_node) # Define this function to retrieve the weight
            total_weight += edge_weight
            shortest_paths_with_weight.append({'source': source, 'target': target, 'path': path, 'total_weight': total_weight})

# Append the result (path and its total weight) to the list
#shortest_paths_with_weight.append({source: source, target: target, path: path, 'total_weight': total_weight})

df1 = pd.DataFrame(shortest_paths_with_weight).copy()
df_shortest_paths_with_weight = df1[(df1['source'].isin(tier2_node_ids)) & (df1['target'].isin(tier0_node_ids))]# & (~df1['source'].isin(tier0_node_ids)) & (~df1['target'].isin(tier2_node_ids))]
#d = df_max[(df_max['source'].isin(tier2_node_ids)) & (df_max['target'].isin(tier0_node_ids)) & (~df_max['source'].isin(tier0_node_ids)) & (~df_max['target'].isin(tier2_node_ids))]
# At this point, shortest_paths_with_weight will contain all paths and their corresponding weights
len(df_shortest_paths_with_weight)
# Out:
# 70

# %%
type(tier2_node_ids)
type(tier2_node_ids[0])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247464 entries, 0 to 247463
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   source        247464 non-null  int64
#  1   target        247464 non-null  int64
#  2   path          247464 non-null  object
#  3   total_weight  247464 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.6+ MB

# %%
# edges = edges.reset_index(drop=True)
# edges.head()

# %%
import networkx as nx
import matplotlib.pyplot as plt


# Example: multiple paths as lists of nodes
#paths = df_min_weight_paths['path']
paths = df_shortest_paths_with_weight['path']
# Create an empty graph
G = nx.DiGraph()

# Add edges from all paths
for path in paths:
# Add edges for consecutive pairs of nodes in the path
    edges_G = list(zip(path[:-1], path[1:]))
    G.add_edges_from(edges_G)

# Draw the graph
pos = nx.spring_layout(G, scale=2,k=0.85, iterations=50) # Layout algorithm for positions
nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500)

# Optionally highlight each path in a different colour
colors = ['red', 'green', 'blue', 'purple']
for path, color in zip(paths, colors):
    edges_zip = list(zip(path[:-1], path[1:]))
    nx.draw_networkx_edges(G, pos, edgelist=edges_zip, edge_color=color, width=2)
#plt.figure(figsize=(12, 8))
plt.title("Multiple Paths in NetworkX Graph")
plt.show()

# %%
len(tier0_node_ids)
# Out:
# 265

# %%
import networkx as nx
import pydot
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import *
# graphviz is installed already, but need lib too
#!apt install libgraphviz-dev
#!pip install pygraphviz
# import pygraphviz as G_pgv

df=df_shortest_paths_with_weight
# df_max1 = []

# df_max1 = df[(df['source'].isin(tier2_node_ids))]# & (df['target'].isin(tier0_node_ids))]

df_max_weight =0
df_max_weight = df_shortest_paths_with_weight['total_weight'].max()
df_max = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == df_max_weight]
#d = df_max[(df_max['source'].isin(tier2_node_ids)) & (df_max['target'].isin(tier0_node_ids)) & (~df_max['source'].isin(tier0_node_ids)) & (~df_max['target'].isin(tier2_node_ids))]

#df.columns = ["source", "target", "path", "weight"]
#sample = df.sample(500, random_state = 1)
#sample.head(10)

G = nx.DiGraph()
#graph [root=new_node_id label=twopi]

for index, row in df_max.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight']

    # Add nodes for all nodes in the path
    for node in path:
        G.add_node(str(node))

    # Add edges for consecutive nodes in the path
    for i in range(len(path) - 1):
        G.add_edge(str(path[i]), str(path[i+1]))
colors = []
#Assuming node 4 is the one to highlight
for node in G.nodes():
    if int(node) in tier0_node_ids:
    #== new_node_id : # Ensure comparison is with string if nodes are strings
        colors.append('red')
        height=6
    elif int(node) in tier1_node_ids:
        colors.append('orange')
        height=4
    elif int(node) in tier2_node_ids:
        colors.append('green')
        height=2
    else:
        colors.append('yellow')

# Set graph attributes to control spacing
# G.graph['ranksep'] = '1.0' # Increase separation between ranks
# G.graph['nodesep'] = '4.0' # Increase separation between nodes

#G_pgv.graph_attr.update(root=new_node_id,ranksep='3.0',nodesep='2.0')
#G_pgv.draw('pytry.jpg',prog='twopi') # This line caused the error
plt.figure(figsize=(12, 12))
# Use pydot_layout with 'twopi' program
pos = pydot_layout(G, prog="twopi")#, root=str(new_node_id)) # Removed root as it might not exist in the graph
nx.draw(G, pos, node_color=colors, with_labels=True, node_size=750, font_weight='normal')

plt.title("Graph Visualization with Twopi Layout")
graph_name_max = suf + '_max_twopi_graph.pdf'
plt.savefig(graph_name_max, format="pdf")
plt.show()

# %%
print(nodes[nodes['id'] == 3167])
print(nodes[nodes['id'] == 3366])
# print(nodes[nodes['id'] == 6452])
# print(nodes[nodes['id'] == 6433])
# print(nodes[nodes['id'] == 6534])
# print(nodes[nodes['id'] == 6458])
# print(nodes[nodes['id'] == 6433])
# Out:
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []

# %%
import networkx as nx
import pydot
import matplotlib.pyplot as plt
from networkx.drawing.nx_pydot import *
# graphviz is installed already, but need lib too
#!apt install libgraphviz-dev
#!pip install pygraphviz
# import pygraphviz as G_pgv

df=df_shortest_paths_with_weight

df_min_weight =2
#df_min_weight = df_shortest_paths_with_weight['total_weight'].min()
df_min = df[(df['total_weight'] == df_min_weight) & (df['target'].isin(tier0_node_ids))]



G = nx.DiGraph()
#graph [root=new_node_id label=twopi]

for index, row in df_min.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight']

    # Add nodes for all nodes in the path
    for node in path:
        G.add_node(str(node))

    # Add edges for consecutive nodes in the path
    for i in range(len(path) - 1):
        G.add_edge(str(path[i]), str(path[i+1]))
colors = []
#Assuming node 4 is the one to highlight
for node in G.nodes():
    if int(node) in tier0_node_ids:
    #== new_node_id : # Ensure comparison is with string if nodes are strings
        colors.append('red')
        height=6
    elif int(node) in tier1_node_ids:
        colors.append('orange')
        height=4
    elif int(node) in tier2_node_ids:
        colors.append('green')
        height=2
    else:
        colors.append('yellow')

# Set graph attributes to control spacing
G.graph['ranksep'] = '2.0' # Increase separation between ranks
G.graph['nodesep'] = '3.0' # Increase separation between nodes

#G_pgv.graph_attr.update(root=new_node_id,ranksep='3.0',nodesep='2.0')
#G_pgv.draw('pytry.jpg',prog='twopi') # This line caused the error
plt.figure(figsize=(12, 12))
# Use pydot_layout with 'twopi' program
pos = pydot_layout(G, prog="twopi", root=str(new_node_id)) # Removed root as it might not exist in the graph
nx.draw(G, pos, node_color=colors, with_labels=True, node_size=650, font_weight='normal')

plt.title("Graph Visualization with Twopi Layout")
graph_name = suf + '_min_twopi_graph.pdf'
plt.savefig(graph_name, format="pdf")
plt.show()

# %%
print(nodes[nodes['id'] == 3167])
print(nodes[nodes['id'] == 3366])
# print(nodes[nodes['id'] == 6452])
# print(nodes[nodes['id'] == 6433])
# print(nodes[nodes['id'] == 6534])
# print(nodes[nodes['id'] == 6458])
# print(nodes[nodes['id'] == 6433])
# Out:
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []
# Empty DataFrame
# Columns: [id, properties, type, l1, l2, l3, weight, Tier0, Tier1, Tier2]
# Index: []

# %%
# admin_nodes = nodes[
#     nodes['properties'].apply(
#         lambda x: isinstance(x, dict) and 'name' in x and 'administrator' in x['name'].lower()
#     )
# ]
# display(admin_nodes)

# %%
edges.head()
# Out:
#    id  source source_node  target target_node          type     label  weight
# 0   0    4248      Domain    4249          OU  relationship  Contains       2
# 1   1    4248      Domain    4250          OU  relationship  Contains       2
# 2   2    4248      Domain    4251          OU  relationship  Contains       2
# 3   3    4249          OU    4252          OU  relationship  Contains       2
# 4   4    4249          OU    4253          OU  relationship  Contains       2

# %%
df_shortest_paths_with_weight.info()


tier2_node_ids = [int(node_id) for node_id in tier2_node_ids]
print(f"Type of elements in tier2_node_ids after conversion: {type(tier2_node_ids[0]) if tier2_node_ids else 'List is empty'}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   source        0 non-null      int64
#  1   target        0 non-null      int64
#  2   path          0 non-null      object
#  3   total_weight  0 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 0.0+ bytes
# Type of elements in tier2_node_ids after conversion: <class 'int'>

# %%
import pandas as pd
from pyvis.network import Network
#pyvis.__version__

#Loading the data
#data = pd.read_csv("facebook_combined.txt", sep=" ", header=None)
df=df_shortest_paths_with_weight


df_min_weight =2
#df_min_weight = df_shortest_paths_with_weight['total_weight'].min()
df_min = df[(df['total_weight'] == df_min_weight) & (df['target'].isin(tier0_node_ids))]

net = Network(notebook = True, cdn_resources = "in_line",
                bgcolor = "#222222",
                font_color = "white",
                height = "750px",
                width = "100%",
                directed=True
)
net.repulsion()
for index, row in df_min.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight'] # Changed 'total_weight' to 'weight'

    # Add nodes for all nodes in the path
    for node in path:
      if node in tier0_node_ids:
        net.add_node(str(node), label=str(node), color='red') # Added label for better visualization
      else:
        net.add_node(str(node), label=str(node), color='green')

    # Add edges for consecutive pairs of nodes in the path
    for i in range(len(path) - 1):
        net.add_edge(str(path[i]), str(path[i+1]), weight=weight, title=f"Weight: {weight}") # Added weight and title to edge
#suf="vul1k"
graph_name = suf + '_min_graph.html'
net.show(graph_name)
# Out:
# vul1k_min_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="vul1k_min_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df_max_weight =0
df_max_weight = df_shortest_paths_with_weight['total_weight'].max()
df_max = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == df_max_weight]







#df.columns = ["source", "target", "path", "weight"]
#sample = df.sample(500, random_state = 1)
#sample.head(10)

net = Network(notebook = True, cdn_resources = "in_line",
                bgcolor = "#222222",
                font_color = "white",
                height = "750px",
                width = "100%",
                directed=True
)
net.repulsion()

for index, row in df_max.iterrows():
    source = row['source']
    target = row['target']
    path = row['path']
    weight = row['total_weight'] # Changed 'total_weight' to 'weight'

    # Add nodes for all nodes in the path
    for node in path:
      if node in tier0_node_ids:
        net.add_node(str(node), label=str(node), color='red') # Added label for better visualization
      elif node in tier1_node_ids:
        net.add_node(str(node), label=str(node), color='orange')
      elif node in tier2_node_ids:
        net.add_node(str(node), label=str(node), color='green')
      else:
        net.add_node(str(node), label=str(node), color='yellow')

    # Add edges for consecutive pairs of nodes in the path
    for i in range(len(path) - 1):
        net.add_edge(str(path[i]), str(path[i+1]), weight=weight, title=f"Weight: {weight}") # Added weight and title to edge
graph_name = suf + '_max_graph.html'
net.show(graph_name)
# Out:
# vul1k_max_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="vul1k_max_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
for index, row in df_max.iterrows():
    path = row['path']
    print(f"Path: {path}")
    for node_id in path:
        # Find the node in the nodes DataFrame
        node_info = nodes[nodes['id'] == node_id]
        if not node_info.empty:
            # Get the properties and check for 'name' and Tier information
            properties = node_info.iloc[0]['properties']
            node_name = properties.get('name', 'N/A')
            is_tier0 = node_info.iloc[0]['Tier0'] == 1
            is_tier1 = node_info.iloc[0]['Tier1'] == 1
            is_tier2 = node_info.iloc[0]['Tier2'] == 1
            print(f"  Node ID: {node_id}, Name: {node_name}, Tier0: {is_tier0}, Tier1: {is_tier1}, Tier2: {is_tier2}")
        else:
            print(f"  Node ID: {node_id} not found in nodes DataFrame.")
    print("-" * 20)

# %%
filtered_shortest_paths = df_shortest_paths_with_weight[df_shortest_paths_with_weight['total_weight'] == 1]
display(filtered_shortest_paths)
# Out:
# Empty DataFrame
# Columns: [source, target, path, total_weight]
# Index: []

# %% [markdown]
# # Stats

# %%
# Create a list to store the data for the table
table_data = []

# Iterate through the paths in df_max
for index, row in df_max.iterrows():
    path = row['path']
    # path_str = " -> ".join(map(str, path)) # Convert the path list to a string

    # Iterate through the nodes in the current path
    for node_id in path:
        # Find the node in the nodes DataFrame
        node_info = nodes[nodes['id'] == node_id]
        if not node_info.empty:
            properties = node_info.iloc[0]['properties']
            node_name = properties.get('name', 'N/A')
            is_tier0 = 1 if node_info.iloc[0]['Tier0'] == 1 else 0
            is_tier1 = 1 if node_info.iloc[0]['Tier1'] == 1 else 0
            is_tier2 = 1 if node_info.iloc[0]['Tier2'] == 1 else 0

            # Append the data as a dictionary to the list
            table_data.append({
                'Node Id': node_id, # Changed 'path' to 'Node Id' and stored node_id
                'Name': node_name,
                'Tier 0': is_tier0,
                'Tier 1': is_tier1,
                'Tier 2': is_tier2
            })

# Create a pandas DataFrame from the list of dictionaries
df_path_info = pd.DataFrame(table_data)

# Display the DataFrame
display(df_path_info)
# Out:
#     Node Id                             Name  Tier 0  Tier 1  Tier 2
# 0      3816          WS-00019@TESTLAB.LOCALE       0       0       1
# 1      3326       RAWONG00034@TESTLAB.LOCALE       1       0       0
# 2      3817          WS-00020@TESTLAB.LOCALE       0       0       1
# 3      3325     NNAUMANN00033@TESTLAB.LOCALE       1       0       0
# 4      3842           S-00009@TESTLAB.LOCALE       0       0       1
# 5      3331        LDRYE00039@TESTLAB.LOCALE       1       0       0
# 6      3850          WS-00036@TESTLAB.LOCALE       0       0       1
# 7      3319  KSTECHUCHAK00027@TESTLAB.LOCALE       1       0       0
# 8      3858          WS-00040@TESTLAB.LOCALE       0       0       1
# 9      3325     NNAUMANN00033@TESTLAB.LOCALE       1       0       0
# 10     3864          WS-00044@TESTLAB.LOCALE       0       0       1
# 11     3325     NNAUMANN00033@TESTLAB.LOCALE       1       0       0
# 12     3872          WS-00049@TESTLAB.LOCALE       0       0       1
# 13     3331        LDRYE00039@TESTLAB.LOCALE       1       0       0
# 14     3902          WS-00069@TESTLAB.LOCALE       0       0       1
# 15     3313      EGROSSO00021@TESTLAB.LOCALE       1       0       0
# 16     3903          WS-00070@TESTLAB.LOCALE       0       0       1
# 17     3329     PGIRLING00037@TESTLAB.LOCALE       1       0       0
# 18     3913           S-00026@TESTLAB.LOCALE       0       0       1
# 19     3325     NNAUMANN00033@TESTLAB.LOCALE       1       0       0
# 20     3913           S-00026@TESTLAB.LOCALE       0       0       1
# 21     3300      GARGOTE00008@TESTLAB.LOCALE       1       0       0
# 22     3916          WS-00078@TESTLAB.LOCALE       0       0       1
# 23     3328     SKLUKKEN00036@TESTLAB.LOCALE       1       0       0
# 24     3918          WS-00080@TESTLAB.LOCALE       0       0       1
# 25     3319  KSTECHUCHAK00027@TESTLAB.LOCALE       1       0       0
# 26     3919          WS-00081@TESTLAB.LOCALE       0       0       1
# 27     3314     CNICOLAU00022@TESTLAB.LOCALE       1       0       0
# 28     3922           S-00028@TESTLAB.LOCALE       0       0       1
# 29     3309      LCLYMAN00017@TESTLAB.LOCALE       1       0       0
# 30     3962          WS-00106@TESTLAB.LOCALE       0       0       1
# 31     3300      GARGOTE00008@TESTLAB.LOCALE       1       0       0
# 32     3981          WS-00120@TESTLAB.LOCALE       0       0       1
# 33     3326       RAWONG00034@TESTLAB.LOCALE       1       0       0
# 34     3993          WS-00127@TESTLAB.LOCALE       0       0       1
# 35     3300      GARGOTE00008@TESTLAB.LOCALE       1       0       0
# 36     4003          WS-00131@TESTLAB.LOCALE       0       0       1
# 37     3326       RAWONG00034@TESTLAB.LOCALE       1       0       0
# 38     4015           S-00045@TESTLAB.LOCALE       0       0       1
# 39     3310      AMETEER00018@TESTLAB.LOCALE       1       0       0
# 40     4016          WS-00137@TESTLAB.LOCALE       0       0       1
# 41     3331        LDRYE00039@TESTLAB.LOCALE       1       0       0
# 42     4017         PAW-00042@TESTLAB.LOCALE       0       0       1
# 43     3331        LDRYE00039@TESTLAB.LOCALE       1       0       0
# 44     4023          WS-00141@TESTLAB.LOCALE       0       0       1
# 45     3300      GARGOTE00008@TESTLAB.LOCALE       1       0       0
# 46     4024           S-00046@TESTLAB.LOCALE       0       0       1
# 47     3326       RAWONG00034@TESTLAB.LOCALE       1       0       0
# 48     4027          WS-00143@TESTLAB.LOCALE       0       0       1
# 49     3314     CNICOLAU00022@TESTLAB.LOCALE       1       0       0
# 50     4038         PAW-00048@TESTLAB.LOCALE       0       0       1
# 51     3306   ADISSINGER00014@TESTLAB.LOCALE       1       0       0
# 52     4046           S-00051@TESTLAB.LOCALE       0       0       1
# 53     3310      AMETEER00018@TESTLAB.LOCALE       1       0       0
# 54     4049         PAW-00051@TESTLAB.LOCALE       0       0       1
# 55     3331        LDRYE00039@TESTLAB.LOCALE       1       0       0
# 56     4056           S-00052@TESTLAB.LOCALE       0       0       1
# 57     3298    JWEGHORST00006@TESTLAB.LOCALE       1       0       0
# 58     4063          WS-00162@TESTLAB.LOCALE       0       0       1
# 59     3325     NNAUMANN00033@TESTLAB.LOCALE       1       0       0
# 60     4064          WS-00163@TESTLAB.LOCALE       0       0       1
# 61     3302     MBODKINS00010@TESTLAB.LOCALE       1       0       0
# 62     4068          WS-00165@TESTLAB.LOCALE       0       0       1
# 63     3310      AMETEER00018@TESTLAB.LOCALE       1       0       0
# 64     4077          WS-00170@TESTLAB.LOCALE       0       0       1
# 65     3341    DBROADDUS00049@TESTLAB.LOCALE       1       0       0
# 66     4079          WS-00171@TESTLAB.LOCALE       0       0       1
# 67     3341    DBROADDUS00049@TESTLAB.LOCALE       1       0       0
# 68     4084          WS-00175@TESTLAB.LOCALE       0       0       1
# 69     3310      AMETEER00018@TESTLAB.LOCALE       1       0       0
# 70     4086           S-00059@TESTLAB.LOCALE       0       0       1
# 71     3313      EGROSSO00021@TESTLAB.LOCALE       1       0       0
# 72     4086           S-00059@TESTLAB.LOCALE       0       0       1
# 73     3314     CNICOLAU00022@TESTLAB.LOCALE       1       0       0
# 74     4088         PAW-00059@TESTLAB.LOCALE       0       0       1
# 75     3319  KSTECHUCHAK00027@TESTLAB.LOCALE       1       0       0

# %%
latex_table = df_path_info.to_latex(index=False)

file_name = suf + "_max_paths_table.tex"

with open(file_name, 'w') as f:
    f.write(latex_table)

print(f"Table exported to {file_name}")
# Out:
# Table exported to vul1k_max_paths_table.tex

# %%
# Out:
# /content/adsync directory created.

# %%
count_weight_2 = selected_edges[selected_edges['weight'] == 2].shape[0]
print(f"Number of records in selected_edges with weight == 2: {count_weight_2}")
# Out:
# Number of records in selected_edges with weight == 2: 304

# %%
weight_distribution = selected_edges['weight'].value_counts().sort_index()
print("Distribution of weights in selected_edges:")
print(weight_distribution)
# Out:
# Distribution of weights in selected_edges:
# weight
# 2    304
# 4      1
# 5      1
# 8      5
# 9    678
# Name: count, dtype: int64

# %%
from collections import Counter
#tier0_node_ids = tier0_node_ids.rename(columns={0: 'id'})

l1 = len(tier0_node_ids)
l2 = len(tier1_node_ids)
l3 = len(tier2_node_ids)
ln1 = len(nodes) -1

amount_of_tier0_nodes = round(l1 / ln1 * 100,3)
print(f"% amount of tier0 nodes: {amount_of_tier0_nodes} %" )

amount_of_tier1_nodes = round(l2 /  ln1 * 100,3)
print(f"% amount of tier1 nodes: {amount_of_tier1_nodes} %" )

amount_of_tier2_nodes = round(l3 /  ln1 * 100,3)
print(f"% amount of tier2 nodes: {amount_of_tier2_nodes} %" )
tot = amount_of_tier2_nodes + amount_of_tier1_nodes + amount_of_tier0_nodes
print(f"% amount of total nodes: {tot} %" )



# l2_counts = Counter(nodes['l2'])
# display(l2_counts)
l2_counts = Counter(nodes['l2'])

# Create a DataFrame from the Counter
l2_counts_df = pd.DataFrame(l2_counts.items(), columns=['Value', 'Count'])
l2_counts_df = l2_counts_df.sort_values(by='Count')

# Convert the DataFrame to a LaTeX table format
latex_table = l2_counts_df.to_latex(index=False)

# Display the LaTeX table output
print(latex_table)
# Out:
# % amount of tier0 nodes: 6.504 %
# % amount of tier1 nodes: 7.859 %
# % amount of tier2 nodes: 76.874 %
# % amount of total nodes: 91.237 %
# \begin{tabular}{lr}
# \toprule
# Value & Count \\
# \midrule
# Domain & 1 \\
# Container & 1 \\
# ALL_T0 & 1 \\
# GPO & 41 \\
# OU & 48 \\
# Group & 202 \\
# Computer & 309 \\
# User & 505 \\
# \bottomrule
# \end{tabular}

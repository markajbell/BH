# %% [markdown]
# <a href="https://colab.research.google.com/github/markajbell/BH/blob/main/Stats_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import os


# !unzip -q stats.zip

# Load the JSON files
with open('vul1k_nodes.json', 'r') as f:
    vul1k_data = json.load(f)

with open('vul5k_nodes.json', 'r') as f:
    vul5k_data = json.load(f)

with open('secure1k_nodes.json', 'r') as f:
    sec1kratios = json.load(f)

with open('secure10k_nodes.json', 'r') as f:
    sec10k_data = json.load(f)

with open('secure50k_nodes.json', 'r') as f:
    sec50k_data = json.load(f)


# Convert JSON data to DataFrames
df_vul1k = pd.DataFrame(list(vul1k_data.items()), columns=['Label', 'vul1k'])
df_vul5k = pd.DataFrame(list(vul5k_data.items()), columns=['Label', 'vul5k'])
df_sec1k = pd.DataFrame(list(sec1k_data.items()), columns=['Label', 'sec1k'])
df_sec10k = pd.DataFrame(list(sec10k_data.items()), columns=['Label', 'sec10k'])
df_sec50k = pd.DataFrame(list(sec50k_data.items()), columns=['Label', 'sec50k'])
#df_vul5k = pd.DataFrame(list(vul5k_data.items()), columns=['Label', 'vul5k'])

# Merge the DataFrames on the 'Label' column
merged_df = pd.merge(df_vul1k, df_vul5k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec1k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec10k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec50k, on='Label', how='outer').fillna(0)


# Sort the DataFrame by 'vul1k_Count' in ascending order
merged_df_sorted = merged_df.sort_values(by='vul1k', ascending=True)

# Display the sorted DataFrame
display(merged_df_sorted)
# Out:
#        Label  vul1k  vul5k  sec1k  sec10k  sec50k
# 0     ALL_T0      1      1      1       1       1
# 2  Container      1      1      1       1       1
# 3     Domain      1      1      1       1       1
# 4        GPO     41     41    181      41      41
# 6         OU     48     48     44      48      48
# 5      Group    202   1769    656    3370    8181
# 1   Computer    309   1609    209    3309   25009
# 7       User    505   1805    205    3305   15005

# %%
import json
import pandas as pd

# Load the JSON files
with open('vul1k_label.json', 'r') as f:
    vul1k_label_data = json.load(f)

with open('vul5k_label.json', 'r') as f:
    vul5k_label_data = json.load(f)

# Convert JSON data to DataFrames
df_vul1k_label = pd.DataFrame(list(vul1k_label_data.items()), columns=['Label', 'vul1k_Label_Count'])
df_vul5k_label = pd.DataFrame(list(vul5k_label_data.items()), columns=['Label', 'vul5k_Label_Count'])

# Merge the DataFrames on the 'Label' column
merged_label_df = pd.merge(df_vul1k_label, df_vul5k_label, on='Label', how='outer').fillna(0)

# Sort the DataFrame by 'vul1k_Label_Count' in ascending order
merged_label_df_sorted = merged_label_df.sort_values(by='vul1k_Label_Count', ascending=True)

# Display the merged and sorted DataFrame
display(merged_label_df_sorted)
# Out:
#                   Label  vul1k_Label_Count  vul5k_Label_Count
# 14        GetChangesAll                  2                  2
# 13           GetChanges                  3                  3
# 0             AddMember                  6                  3
# 18                 Owns                  6                  6
# 10  ForceChangePassword                  8                  7
# 20             SQLAdmin                 12                121
# 1               AddSelf                 15                 11
# 4          AllowedToAct                 16                123
# 6           CanPSRemote                 18                110
# 7                CanRDP                 20                136
# 9           ExecuteDCOM                 22                149
# 19     ReadLAPSPassword                 23                115
# 5     AllowedToDelegate                 26                142
# 3     AllExtendedRights                 26                 30
# ...

# %%
# Save the merged and sorted DataFrame to a JSON file
merged_df_sorted.to_json('all_nodes.json', orient='records', indent=4)

print("merged_df_sorted saved to all_nodes.json")
# Out:
# merged_df_sorted saved to all_nodes.json

# %%
import pandas as pd
import json

# Load the JSON files
with open('vul1k_label.json', 'r') as f:
    vul1k_data = json.load(f)

with open('vul5k_label.json', 'r') as f:
    vul5k_data = json.load(f)

with open('secure1k_label.json', 'r') as f:
    sec1k_data = json.load(f)

with open('secure10k_label.json', 'r') as f:
    sec10k_data = json.load(f)

with open('secure50k_label.json', 'r') as f:
    sec50k_data = json.load(f)


# Convert JSON data to DataFrames
df_vul1k = pd.DataFrame(list(vul1k_data.items()), columns=['Label', 'vul1k_label'])
df_vul5k = pd.DataFrame(list(vul5k_data.items()), columns=['Label', 'vul5k_label'])
df_sec1k = pd.DataFrame(list(sec1k_data.items()), columns=['Label', 'sec1k_label'])
df_sec10k = pd.DataFrame(list(sec10k_data.items()), columns=['Label', 'sec10k_label'])
df_sec50k = pd.DataFrame(list(sec50k_data.items()), columns=['Label', 'sec50k_label'])


# Merge the DataFrames on the 'Label' column
merged_df = pd.merge(df_vul1k, df_vul5k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec1k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec10k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec50k, on='Label', how='outer').fillna(0)


# Sort the DataFrame by 'vul1k_label' in ascending order
merged_df_sorted = merged_df.sort_values(by='vul1k_label', ascending=True)

# Display the sorted DataFrame
display(merged_df_sorted)
# Out:
#                   Label  vul1k_label  vul5k_label  sec1k_label  sec10k_label  \
# 5    AllowedToDe,legate          0.0          0.0          0.0           0.0
# 15        GetChangesAll          2.0          2.0          2.0           2.0
# 14           GetChanges          3.0          3.0          3.0           3.0
# 0             AddMember          6.0          3.0         14.0          11.0
# 19                 Owns          6.0          6.0         53.0           6.0
# 11  ForceChangePassword          8.0          7.0         15.0           8.0
# 21             SQLAdmin         12.0        121.0          0.0           0.0
# 1               AddSelf         15.0         11.0         13.0           3.0
# 4          AllowedToAct         16.0        123.0          0.0           4.0
# 7           CanPSRemote         18.0        110.0          0.0           1.0
# 8                CanRDP         20.0        136.0          3.0           4.0
# ...

# %%
# Save the merged and sorted DataFrame to a JSON file
merged_df_sorted.to_json('all_label.json', orient='records', indent=4)

print("merged_df_sorted saved to all_nodes.json")
# Out:
# merged_df_sorted saved to all_nodes.json

# %%
import pandas as pd
import json

# Load the JSON files
with open('vul1kratios.json', 'r') as f:
    vul1kratios = json.load(f)

with open('vul5kratios.json', 'r') as f:
    vul5kratios = json.load(f)

with open('secure1kratios.json', 'r') as f:
    sec1kratios = json.load(f)

with open('secure10kratios.json', 'r') as f:
    sec10kratios = json.load(f)

with open('secure50kratios.json', 'r') as f:
    sec50kratios = json.load(f)


# Convert JSON data to DataFrames
df_vul1k = pd.DataFrame(list(vul1kratios.items()), columns=['Label', 'vul1k'])
df_vul5k = pd.DataFrame(list(vul5kratios.items()), columns=['Label', 'vul5k'])
df_sec1k = pd.DataFrame(list(sec1kratios.items()), columns=['Label', 'sec1k'])
df_sec10k = pd.DataFrame(list(sec10kratios.items()), columns=['Label', 'sec10k'])
df_sec50k = pd.DataFrame(list(sec50kratios.items()), columns=['Label', 'sec50k'])


# Merge the DataFrames on the 'Label' column
merged_df = pd.merge(df_vul1k, df_vul5k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec1k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec10k, on='Label', how='outer')
merged_df = pd.merge(merged_df, df_sec50k, on='Label', how='outer').fillna(0)


# Sort the DataFrame by 'vul1k_label' in ascending order
merged_df_sorted = merged_df.sort_values(by='vul1k_label', ascending=True)

# Display the sorted DataFrame
display(merged_df_sorted)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-766778508.py in <cell line: 0>()
#      35
#      36 # Sort the DataFrame by 'vul1k_label' in ascending order
# ---> 37 merged_df_sorted = merged_df.sort_values(by='vul1k_label', ascending=True)
#      38
#      39 # Display the sorted DataFrame
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
# ...

# %%
# Extract the nested 'values' dictionary
df_vul1k['values'] = df_vul1k['vul1k'].apply(lambda x: x.get('values', {}))

# Extract 'Ratio', 'ratio_min', and 'ratio_max' into new columns
df_vul1k['Ratio'] = df_vul1k['values'].apply(lambda x: x.get('Ratio'))
df_vul1k['ratio_min'] = df_vul1k['values'].apply(lambda x: x.get('ratio_min'))
df_vul1k['ratio_max'] = df_vul1k['values'].apply(lambda x: x.get('ratio_max'))

# Display the updated DataFrame
display(df_vul1k)
# Out:
#    Label                                              vul1k  \
# 0  vul1k  {'values': {'Ratio': 15.48, 'ratio_min': 0.62,...
#
#                                               values  Ratio  ratio_min  \
# 0  {'Ratio': 15.48, 'ratio_min': 0.62, 'ratio_max...  15.48       0.62
#
#    ratio_max
# 0       0.53

# %%
# Drop the original 'vul1k' and 'values' columns
df_vul1k = df_vul1k.drop(columns=['vul1k', 'values'])

# Display the updated DataFrame
display(df_vul1k)
# Out:
#    Label  Ratio  ratio_min  ratio_max
# 0  vul1k  15.48       0.62       0.53

# %%
# Select the relevant columns and transpose the DataFrame
df_vul1k_transposed = df_vul1k[['Ratio', 'ratio_min', 'ratio_max']].T

# Rename the column header to 'vul1k'
df_vul1k_transposed.columns = ['vul1k']

# Display the transformed DataFrame
display(df_vul1k_transposed)
# Out:
#            vul1k
# Ratio      15.48
# ratio_min   0.62
# ratio_max   0.53

# %% [markdown]
# # Task
# Transform the dataframes `df_vul1k`, `df_vul5k`, `df_sec1k`, `df_sec10k`, and `df_sec50k` by extracting the values from the 'vul1k' column (and equivalent columns in other dataframes) into three new columns, dropping the original columns, transposing the resulting dataframes, and then merging them into a single dataframe.

# %% [markdown]
# ## Transform `df vul5k`
#
# ### Subtask:
# Extract 'Ratio', 'ratio_min', and 'ratio_max' from the 'vul5k' column in `df_vul5k`, drop the original columns, and transpose the DataFrame.

# %% [markdown]
# **Reasoning**:
# Extract the nested 'values' dictionary, the 'Ratio', 'ratio_min', and 'ratio_max' from the 'vul5k' column in `df_vul5k`, drop the original 'vul5k' and temporary 'values' columns, and then transpose the DataFrame.

# %%
# Extract the nested 'values' dictionary
df_vul5k['values'] = df_vul5k['vul5k'].apply(lambda x: x.get('values', {}))

# Extract 'Ratio', 'ratio_min', and 'ratio_max' into new columns
df_vul5k['Ratio'] = df_vul5k['values'].apply(lambda x: x.get('Ratio'))
df_vul5k['ratio_min'] = df_vul5k['values'].apply(lambda x: x.get('ratio_min'))
df_vul5k['ratio_max'] = df_vul5k['values'].apply(lambda x: x.get('ratio_max'))

# Drop the original 'vul5k' and 'values' columns
df_vul5k = df_vul5k.drop(columns=['vul5k', 'values'])

# Select the relevant columns and transpose the DataFrame
df_vul5k_transposed = df_vul5k[['Ratio', 'ratio_min', 'ratio_max']].T

# Rename the column header to 'vul5k'
df_vul5k_transposed.columns = ['vul5k']

# Display the transformed DataFrame
display(df_vul5k_transposed)
# Out:
#            vul5k
# Ratio      18.45
# ratio_min   0.00
# ratio_max   2.37

# %% [markdown]
# ## Transform
#
# ### Subtask:
# Extract 'Ratio', 'ratio_min', and 'ratio_max' from the 'sec1k' column in `df_sec1k`, drop the original columns, and transpose the DataFrame.

# %% [markdown]
# **Reasoning**:
# Extract 'Ratio', 'ratio_min', and 'ratio_max' from the 'sec1k' column, drop the original columns, and transpose the DataFrame, then rename the column.

# %%
# Extract the nested 'values' dictionary
df_sec1k['values'] = df_sec1k['sec1k'].apply(lambda x: x.get('values', {}))

# Extract 'Ratio', 'ratio_min', and 'ratio_max' into new columns
df_sec1k['Ratio'] = df_sec1k['values'].apply(lambda x: x.get('Ratio'))
df_sec1k['ratio_min'] = df_sec1k['values'].apply(lambda x: x.get('ratio_min'))
df_sec1k['ratio_max'] = df_sec1k['values'].apply(lambda x: x.get('ratio_max'))

# Drop the original 'sec1k' and 'values' columns
df_sec1k = df_sec1k.drop(columns=['sec1k', 'values'])

# Select the relevant columns and transpose the DataFrame
df_sec1k_transposed = df_sec1k[['Ratio', 'ratio_min', 'ratio_max']].T

# Rename the column header to 'sec1k'
df_sec1k_transposed.columns = ['sec1k']

# Display the transformed DataFrame
display(df_sec1k_transposed)
# Out:
#            sec1k
# Ratio      32.22
# ratio_min   0.35
# ratio_max   1.07

# %% [markdown]
# ## Transform `df sec10k`
#
# ### Subtask:
# Extract 'Ratio', 'ratio_min', and 'ratio_max' from the 'sec10k' column in `df_sec10k`, drop the original columns, and transpose the DataFrame.

# %% [markdown]
# **Reasoning**:
# Extract the nested 'values' dictionary from the 'sec10k' column, extract the specific ratio values, drop the original and temporary columns, transpose the DataFrame, rename the column, and display the result as per the instructions.

# %%
# Extract the nested 'values' dictionary
df_sec10k['values'] = df_sec10k['sec10k'].apply(lambda x: x.get('values', {}))

# Extract 'Ratio', 'ratio_min', and 'ratio_max' into new columns
df_sec10k['Ratio'] = df_sec10k['values'].apply(lambda x: x.get('Ratio'))
df_sec10k['ratio_min'] = df_sec10k['values'].apply(lambda x: x.get('ratio_min'))
df_sec10k['ratio_max'] = df_sec10k['values'].apply(lambda x: x.get('ratio_max'))

# Drop the original 'sec10k' and 'values' columns
df_sec10k = df_sec10k.drop(columns=['sec10k', 'values'])

# Select the relevant columns and transpose the DataFrame
df_sec10k_transposed = df_sec10k[['Ratio', 'ratio_min', 'ratio_max']].T

# Rename the column header to 'sec10k'
df_sec10k_transposed.columns = ['sec10k']

# Display the transformed DataFrame
display(df_sec10k_transposed)
# Out:
#            sec10k
# Ratio       20.63
# ratio_min    0.36
# ratio_max    1.88

# %% [markdown]
# ## Transform `df sec50k`
#
# ### Subtask:
# Extract 'Ratio', 'ratio_min', and 'ratio_max' from the 'sec50k' column in `df_sec50k`, drop the original columns, and transpose the DataFrame.

# %% [markdown]
# **Reasoning**:
# Extract the nested 'values' dictionary from the 'sec50k' column, extract 'Ratio', 'ratio_min', and 'ratio_max' into new columns, drop the original and temporary columns, transpose the DataFrame, rename the column, and display the result.

# %%
# Extract the nested 'values' dictionary
df_sec50k['values'] = df_sec50k['sec50k'].apply(lambda x: x.get('values', {}))

# Extract 'Ratio', 'ratio_min', and 'ratio_max' into new columns
df_sec50k['Ratio'] = df_sec50k['values'].apply(lambda x: x.get('Ratio'))
df_sec50k['ratio_min'] = df_sec50k['values'].apply(lambda x: x.get('ratio_min'))
df_sec50k['ratio_max'] = df_sec50k['values'].apply(lambda x: x.get('ratio_max'))

# Drop the original 'sec50k' and 'values' columns
df_sec50k = df_sec50k.drop(columns=['sec50k', 'values'])

# Select the relevant columns and transpose the DataFrame
df_sec50k_transposed = df_sec50k[['Ratio', 'ratio_min', 'ratio_max']].T

# Rename the column header to 'sec50k'
df_sec50k_transposed.columns = ['sec50k']

# Display the transformed DataFrame
display(df_sec50k_transposed)
# Out:
#            sec50k
# Ratio       20.26
# ratio_min    0.20
# ratio_max    1.17

# %% [markdown]
# ## Merge dataframes
#
# ### Subtask:
# Merge the transformed DataFrames into a single DataFrame.

# %% [markdown]
# **Reasoning**:
# Merge the transposed dataframes into a single dataframe.

# %%
merged_ratios_df = pd.concat([df_vul1k_transposed, df_vul5k_transposed, df_sec1k_transposed, df_sec10k_transposed, df_sec50k_transposed], axis=1)

# Display the merged DataFrame
display(merged_ratios_df)
# Out:
#            vul1k  vul5k  sec1k  sec10k  sec50k
# Ratio      15.48  18.45  32.22   20.63   20.26
# ratio_min   0.62   0.00   0.35    0.36    0.20
# ratio_max   0.53   2.37   1.07    1.88    1.17

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The 'Ratio', 'ratio\_min', and 'ratio\_max' values were successfully extracted from the nested dictionaries within the specified columns ('vul1k', 'vul5k', 'sec1k', 'sec10k', and 'sec50k') of the initial dataframes.
# *   The original columns containing the nested data and the temporary 'values' columns were successfully dropped from each dataframe.
# *   Each of the processed dataframes (`df_vul1k`, `df_vul5k`, `df_sec1k`, `df_sec10k`, and `df_sec50k`) was successfully transposed, resulting in new dataframes (`df_vul1k_transposed`, `df_vul5k_transposed`, `df_sec1k_transposed`, `df_sec10k_transposed`, and `df_sec50k_transposed`) where 'Ratio', 'ratio\_min', and 'ratio\_max' became the index and the original column name (e.g., 'vul1k') became the single column header.
# *   The five transposed dataframes were successfully merged into a single dataframe, `merged_ratios_df`, with columns representing the original dataframes and rows representing the extracted ratio types.
#
# ### Insights or Next Steps
#
# *   The merged dataframe provides a consolidated view of the ratio metrics across different categories ('vul1k', 'vul5k', 'sec1k', 'sec10k', 'sec50k'), facilitating comparison.
# *   The next step could involve analyzing the merged data to identify trends or significant differences in ratios between the categories.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reset the index to make 'Ratio', 'ratio_min', and 'ratio_max' a column
merged_ratios_df_reset = merged_ratios_df.reset_index()

# Melt the DataFrame to long format for easier plotting
merged_ratios_melted = merged_ratios_df_reset.melt(id_vars='index', var_name='Category', value_name='Value')

# Create a line graph with a logarithmic y-axis
plt.figure(figsize=(12, 6))
sns.lineplot(x='index', y='Value', hue='Category', data=merged_ratios_melted, marker='o')
plt.title('Ratio Metrics Across Categories (Line Graph - Log Scale)')
plt.xlabel('Ratio Type')
plt.ylabel('Value (Log Scale)')
plt.yscale('log') # Set y-axis to logarithmic scale
plt.grid(True)

# Add annotations for ratio_max values for vul1k and sec1k
offset = 10  # Base vertical offset
for i, category in enumerate(merged_ratios_melted['Category'].unique()):
    if category in ['vul1k', 'sec1k']: # Only add label for vul1k and sec1k
        ratio_max_data = merged_ratios_melted[(merged_ratios_melted['Category'] == category) & (merged_ratios_melted['index'] == 'ratio_max')]
        if not ratio_max_data.empty:
            x_val = ratio_max_data['index'].iloc[0]
            y_val = ratio_max_data['Value'].iloc[0]
            # Apply alternating offset
            vertical_offset = offset * ((-1)**i)
            plt.annotate(f'{y_val:.2f}', (x_val, y_val), textcoords="offset points", xytext=(0, vertical_offset), ha='center')


# Save the plot as a PNG file
plt.savefig('Ratio_plot.png')

plt.show()
